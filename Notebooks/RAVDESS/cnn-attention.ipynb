# %% [markdown]
# # Load file names

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'}
DATA_PATH = '/kaggle/input/ravdess-emotional-speech-audio'
SAMPLE_RATE = 48000

data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender', 'Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join('/kaggle/input/', dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = int(identifiers[2])
        if emotion == 8:
            emotion = 0
        emotion_intensity = 'normal' if int(identifiers[3]) == 1 else 'strong'
        gender = 'female' if int(identifiers[6]) % 2 == 0 else 'male'
        
        new_row = pd.DataFrame({
            "Emotion": [emotion],
            "Emotion intensity": [emotion_intensity],
            "Gender": [gender],
            "Path": [file_path]
        })
        data = pd.concat([data, new_row], ignore_index=True)

print(data)
# Out:
#      Emotion Emotion intensity  Gender  \
# 0          0            normal  female
# 1          1            normal  female
# 2          7            strong  female
# 3          7            normal  female
# 4          1            normal  female
# ...      ...               ...     ...
# 2875       6            normal    male
# 2876       5            normal    male
# 2877       4            strong    male
# 2878       7            strong    male
# 2879       5            strong    male
#
#                                                    Path
# 0     /kaggle/input/ravdess-emotional-speech-audio/A...
# 1     /kaggle/input/ravdess-emotional-speech-audio/A...
# 2     /kaggle/input/ravdess-emotional-speech-audio/A...
# 3     /kaggle/input/ravdess-emotional-speech-audio/A...
# 4     /kaggle/input/ravdess-emotional-speech-audio/A...
# ...                                                 ...
# 2875  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2876  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2877  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2878  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2879  /kaggle/input/ravdess-emotional-speech-audio/A...
#
# [2880 rows x 4 columns]

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 2880
#   Emotion Emotion intensity  Gender  \
# 0       0            normal  female
# 1       1            normal  female
# 2       7            strong  female
# 3       7            normal  female
# 4       1            normal  female
#
#                                                 Path
# 0  /kaggle/input/ravdess-emotional-speech-audio/A...
# 1  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2  /kaggle/input/ravdess-emotional-speech-audio/A...
# 3  /kaggle/input/ravdess-emotional-speech-audio/A...
# 4  /kaggle/input/ravdess-emotional-speech-audio/A...

# %% [markdown]
# Number of examples per emotion

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per gender

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per emotion intensity

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# # Load the signals

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 2879/2880 files

# %% [markdown]
# # Split the data

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(2302, 144000), Y_train:(2302,)
# X_val:(285, 144000), Y_val:(285,)
# X_test:(293, 144000), Y_test:(293,)
# Number of unique indexes is 2880, out of 2880

# %% [markdown]
# # Augment signals by adding AWGN

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
for i in range(X_train.shape[0]):
    signal = X_train[i, :]
    augmented_signals = addAWGN(signal)
    for j in range(augmented_signals.shape[0]):
        aug_labels.append(Y_train[i])
        aug_signals.append(augmented_signals[j])
    print("\rProcessed {}/{} files".format(i + 1, X_train.shape[0]), end='')

aug_signals = np.stack(aug_signals, axis=0)
X_train = np.concatenate([X_train, aug_signals], axis=0)
aug_labels = np.stack(aug_labels, axis=0)
Y_train = np.concatenate([Y_train, aug_labels])

print('')
print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
# Out:
# Processed 2302/2302 files
# X_train: (6906, 144000), Y_train: (6906,)

# %% [markdown]
# # Calculate mel spectrograms

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculatin mel spectrograms for train set
#  Processed 6905/6906 files
# Calculatin mel spectrograms for val set
#  Processed 284/285 files
# Calculatin mel spectrograms for test set
#  Processed 292/293 files
# X_train:(6906, 128, 563), Y_train:(6906,)
# X_val:(285, 128, 563), Y_val:(285,)
# X_test:(293, 128, 563), Y_test:(293,)

# %% [markdown]
# # Create the model

# %%
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # LSTM block
        self.lstm_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        hidden_size = 128
        self.lstm = nn.LSTM(input_size=64,hidden_size=hidden_size,bidirectional=True, batch_first=True)
        self.dropout_lstm = nn.Dropout(0.1)
        self.attention_linear = nn.Linear(2*hidden_size,1) # 2*hidden_size for the 2 outputs of bidir LSTM
        # Linear softmax layer
        self.out_linear = nn.Linear(2*hidden_size+256,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1) # do not flatten batch dimension
        # lstm embedding
        x_reduced = self.lstm_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(0,2,1) # (b,t,freq)
        lstm_embedding, (h,c) = self.lstm(x_reduced) # (b, time, hidden_size*2)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        batch_size,T,_ = lstm_embedding.shape 
        attention_weights = [None]*T
        for t in range(T):
            embedding = lstm_embedding[:,t,:]
            attention_weights[t] = self.attention_linear(embedding)
        attention_weights_norm = nn.functional.softmax(torch.stack(attention_weights,-1),-1)
        attention = torch.bmm(attention_weights_norm,lstm_embedding) # (Bx1xT)*(B,T,hidden_size*2)=(B,1,2*hidden_size)
        attention = torch.squeeze(attention, 1)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, attention], dim=1) 
        
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax, attention_weights_norm

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %% [markdown]
# # TRAINING

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax, attention_weights_norm = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax, attention_weights_norm = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# scale data

# %%
from sklearn.preprocessing import StandardScaler

X_train = np.expand_dims(X_train,1)
X_val = np.expand_dims(X_val,1)
X_test = np.expand_dims(X_test,1)

scaler = StandardScaler()

b,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,c,h,w))

b,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,c,h,w))

b,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,c,h,w))

# %% [markdown]
# Train the model

# %%
EPOCHS=100
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  263593
#  Epoch 0: iteration 214/215
# Epoch 0 --> loss:2.0381, acc:23.70%, val_loss:2.1432, val_acc:22.11%
#  Epoch 1: iteration 214/215
# Epoch 1 --> loss:1.7073, acc:35.55%, val_loss:1.6424, val_acc:38.60%
#  Epoch 2: iteration 214/215
# Epoch 2 --> loss:1.5651, acc:40.50%, val_loss:1.5722, val_acc:38.60%
#  Epoch 3: iteration 214/215
# Epoch 3 --> loss:1.4805, acc:44.09%, val_loss:1.4803, val_acc:46.67%
#  Epoch 4: iteration 214/215
# Epoch 4 --> loss:1.3848, acc:47.47%, val_loss:1.5047, val_acc:44.56%
#  Epoch 5: iteration 214/215
# Epoch 5 --> loss:1.3400, acc:49.07%, val_loss:1.3304, val_acc:49.47%
#  Epoch 6: iteration 214/215
# Epoch 6 --> loss:1.2572, acc:52.30%, val_loss:1.3032, val_acc:50.18%
#  Epoch 7: iteration 214/215
# Epoch 7 --> loss:1.2060, acc:53.75%, val_loss:1.1465, val_acc:57.89%
#  Epoch 8: iteration 214/215
# Epoch 8 --> loss:1.1635, acc:55.79%, val_loss:1.2918, val_acc:51.93%
#  Epoch 9: iteration 214/215
# Epoch 9 --> loss:1.1156, acc:57.18%, val_loss:1.2020, val_acc:55.79%
#  Epoch 10: iteration 214/215
# Epoch 10 --> loss:1.0482, acc:61.31%, val_loss:1.0617, val_acc:58.95%
#  Epoch 11: iteration 214/215
# Epoch 11 --> loss:1.0062, acc:61.67%, val_loss:1.0654, val_acc:62.11%
#  Epoch 12: iteration 214/215
# Epoch 12 --> loss:0.9597, acc:64.90%, val_loss:1.0591, val_acc:59.65%
#  Epoch 13: iteration 214/215
# Epoch 13 --> loss:0.9055, acc:65.97%, val_loss:0.9956, val_acc:62.11%
#  Epoch 14: iteration 214/215
# Epoch 14 --> loss:0.8659, acc:67.87%, val_loss:0.9557, val_acc:65.61%
#  Epoch 15: iteration 214/215
# Epoch 15 --> loss:0.8013, acc:70.43%, val_loss:0.9577, val_acc:64.21%
#  Epoch 16: iteration 214/215
# Epoch 16 --> loss:0.7705, acc:71.56%, val_loss:0.7362, val_acc:76.84%
#  Epoch 17: iteration 214/215
# Epoch 17 --> loss:0.7223, acc:73.65%, val_loss:0.7531, val_acc:73.33%
#  Epoch 18: iteration 214/215
# Epoch 18 --> loss:0.6895, acc:74.69%, val_loss:0.7101, val_acc:75.44%
#  Epoch 19: iteration 214/215
# Epoch 19 --> loss:0.6407, acc:76.82%, val_loss:0.7731, val_acc:71.23%
#  Epoch 20: iteration 214/215
# Epoch 20 --> loss:0.6204, acc:77.73%, val_loss:0.6467, val_acc:78.60%
#  Epoch 21: iteration 214/215
# Epoch 21 --> loss:0.5631, acc:79.42%, val_loss:0.6254, val_acc:78.25%
#  Epoch 22: iteration 214/215
# Epoch 22 --> loss:0.5317, acc:81.16%, val_loss:0.6070, val_acc:78.95%
#  Epoch 23: iteration 214/215
# Epoch 23 --> loss:0.5049, acc:81.61%, val_loss:0.5215, val_acc:83.51%
#  Epoch 24: iteration 214/215
# Epoch 24 --> loss:0.4658, acc:83.30%, val_loss:0.4988, val_acc:83.16%
#  Epoch 25: iteration 214/215
# Epoch 25 --> loss:0.4304, acc:84.81%, val_loss:0.4790, val_acc:85.26%
#  Epoch 26: iteration 214/215
# Epoch 26 --> loss:0.3999, acc:86.33%, val_loss:0.4408, val_acc:86.32%
#  Epoch 27: iteration 214/215
# Epoch 27 --> loss:0.3688, acc:87.08%, val_loss:0.3716, val_acc:87.72%
#  Epoch 28: iteration 214/215
# Epoch 28 --> loss:0.3527, acc:87.53%, val_loss:0.4419, val_acc:84.56%
#  Epoch 29: iteration 214/215
# Epoch 29 --> loss:0.3299, acc:89.02%, val_loss:0.4715, val_acc:84.91%
#  Epoch 30: iteration 214/215
# Epoch 30 --> loss:0.3084, acc:89.46%, val_loss:0.3344, val_acc:90.53%
#  Epoch 31: iteration 214/215
# Epoch 31 --> loss:0.2861, acc:90.04%, val_loss:0.3642, val_acc:87.72%
#  Epoch 32: iteration 214/215
# Epoch 32 --> loss:0.2664, acc:91.14%, val_loss:0.4112, val_acc:85.61%
#  Epoch 33: iteration 214/215
# Epoch 33 --> loss:0.2653, acc:90.69%, val_loss:0.3384, val_acc:91.23%
#  Epoch 34: iteration 214/215
# Epoch 34 --> loss:0.2413, acc:91.91%, val_loss:0.3717, val_acc:89.12%
#  Epoch 35: iteration 214/215
# Epoch 35 --> loss:0.2164, acc:92.90%, val_loss:0.3361, val_acc:91.93%
#  Epoch 36: iteration 214/215
# Epoch 36 --> loss:0.2156, acc:92.82%, val_loss:0.3193, val_acc:91.23%
#  Epoch 37: iteration 214/215
# Epoch 37 --> loss:0.2120, acc:92.72%, val_loss:0.2829, val_acc:92.63%
#  Epoch 38: iteration 214/215
# Epoch 38 --> loss:0.1985, acc:93.18%, val_loss:0.3046, val_acc:93.33%
#  Epoch 39: iteration 214/215
# Epoch 39 --> loss:0.1855, acc:93.80%, val_loss:0.2809, val_acc:93.33%
#  Epoch 40: iteration 214/215
# Epoch 40 --> loss:0.1784, acc:94.22%, val_loss:0.2840, val_acc:95.79%
#  Epoch 41: iteration 214/215
# Epoch 41 --> loss:0.1585, acc:94.90%, val_loss:0.3017, val_acc:92.98%
#  Epoch 42: iteration 214/215
# Epoch 42 --> loss:0.1735, acc:94.35%, val_loss:0.3658, val_acc:90.18%
#  Epoch 43: iteration 214/215
# Epoch 43 --> loss:0.1549, acc:94.95%, val_loss:0.3098, val_acc:92.63%
#  Epoch 44: iteration 214/215
# Epoch 44 --> loss:0.1355, acc:95.67%, val_loss:0.2810, val_acc:93.68%
#  Epoch 45: iteration 214/215
# Epoch 45 --> loss:0.1285, acc:95.84%, val_loss:0.3067, val_acc:93.68%
#  Epoch 46: iteration 214/215
# Epoch 46 --> loss:0.1395, acc:95.51%, val_loss:0.2736, val_acc:94.39%
#  Epoch 47: iteration 214/215
# Epoch 47 --> loss:0.1165, acc:96.44%, val_loss:0.3523, val_acc:90.53%
#  Epoch 48: iteration 214/215
# Epoch 48 --> loss:0.1078, acc:96.58%, val_loss:0.2654, val_acc:93.68%
#  Epoch 49: iteration 214/215
# Epoch 49 --> loss:0.1223, acc:95.99%, val_loss:0.3614, val_acc:91.93%
#  Epoch 50: iteration 214/215
# Epoch 50 --> loss:0.1359, acc:95.61%, val_loss:0.2123, val_acc:95.09%
#  Epoch 51: iteration 214/215
# Epoch 51 --> loss:0.1150, acc:96.41%, val_loss:0.2303, val_acc:93.33%
#  Epoch 52: iteration 214/215
# Epoch 52 --> loss:0.0933, acc:97.10%, val_loss:0.3697, val_acc:92.98%
#  Epoch 53: iteration 214/215
# Epoch 53 --> loss:0.0865, acc:97.38%, val_loss:0.2582, val_acc:95.09%
#  Epoch 54: iteration 214/215
# Epoch 54 --> loss:0.0967, acc:96.97%, val_loss:0.3144, val_acc:92.63%
#  Epoch 55: iteration 214/215
# Epoch 55 --> loss:0.0968, acc:97.02%, val_loss:0.3144, val_acc:94.04%
#  Epoch 56: iteration 214/215
# Epoch 56 --> loss:0.1072, acc:96.70%, val_loss:0.2921, val_acc:93.68%
#  Epoch 57: iteration 214/215
# Epoch 57 --> loss:0.0821, acc:97.49%, val_loss:0.2981, val_acc:92.98%
#  Epoch 58: iteration 214/215
# Epoch 58 --> loss:0.0936, acc:97.05%, val_loss:0.3379, val_acc:90.53%
#  Epoch 59: iteration 214/215
# Epoch 59 --> loss:0.0744, acc:97.74%, val_loss:0.2390, val_acc:95.09%
#  Epoch 60: iteration 214/215
# Epoch 60 --> loss:0.0704, acc:97.86%, val_loss:0.2481, val_acc:94.39%
#  Epoch 61: iteration 214/215
# Epoch 61 --> loss:0.0727, acc:97.73%, val_loss:0.3599, val_acc:90.18%
#  Epoch 62: iteration 214/215
# Epoch 62 --> loss:0.0950, acc:96.94%, val_loss:0.2618, val_acc:93.68%
#  Epoch 63: iteration 214/215
# Epoch 63 --> loss:0.0751, acc:97.60%, val_loss:0.3016, val_acc:94.04%
#  Epoch 64: iteration 214/215
# Epoch 64 --> loss:0.0651, acc:97.96%, val_loss:0.2942, val_acc:94.39%
#  Epoch 65: iteration 214/215
# Epoch 65 --> loss:0.0935, acc:96.89%, val_loss:0.2498, val_acc:94.74%
#  Epoch 66: iteration 214/215
# Epoch 66 --> loss:0.0777, acc:97.54%, val_loss:0.2754, val_acc:92.98%
#  Epoch 67: iteration 214/215
# Epoch 67 --> loss:0.0819, acc:97.73%, val_loss:0.3068, val_acc:92.63%
#  Epoch 68: iteration 214/215
# Epoch 68 --> loss:0.0810, acc:97.45%, val_loss:0.2969, val_acc:93.68%
#  Epoch 69: iteration 214/215
# Epoch 69 --> loss:0.0516, acc:98.65%, val_loss:0.2264, val_acc:95.09%
#  Epoch 70: iteration 214/215
# Epoch 70 --> loss:0.0510, acc:98.33%, val_loss:0.2613, val_acc:93.68%
#  Epoch 71: iteration 214/215
# Epoch 71 --> loss:0.0692, acc:97.77%, val_loss:0.2090, val_acc:94.39%
#  Epoch 72: iteration 214/215
# Epoch 72 --> loss:0.0695, acc:97.86%, val_loss:0.2081, val_acc:95.09%
#  Epoch 73: iteration 214/215
# Epoch 73 --> loss:0.0669, acc:97.99%, val_loss:0.2105, val_acc:95.09%
#  Epoch 74: iteration 214/215
# Epoch 74 --> loss:0.0700, acc:97.89%, val_loss:0.3571, val_acc:90.88%
#  Epoch 75: iteration 214/215
# Epoch 75 --> loss:0.0764, acc:97.61%, val_loss:0.2386, val_acc:94.39%
#  Epoch 76: iteration 214/215
# Epoch 76 --> loss:0.0841, acc:97.16%, val_loss:0.2274, val_acc:94.74%
#  Epoch 77: iteration 214/215
# Epoch 77 --> loss:0.0528, acc:98.52%, val_loss:0.2398, val_acc:94.04%
#  Epoch 78: iteration 214/215
# Epoch 78 --> loss:0.0424, acc:98.78%, val_loss:0.2811, val_acc:94.04%
#  Epoch 79: iteration 214/215
# Epoch 79 --> loss:0.0455, acc:98.57%, val_loss:0.2527, val_acc:94.39%
#  Epoch 80: iteration 214/215
# Epoch 80 --> loss:0.0495, acc:98.49%, val_loss:0.2799, val_acc:93.68%
#  Epoch 81: iteration 214/215
# Epoch 81 --> loss:0.0760, acc:97.58%, val_loss:0.1949, val_acc:94.04%
#  Epoch 82: iteration 214/215
# Epoch 82 --> loss:0.0550, acc:98.31%, val_loss:0.1738, val_acc:94.74%
#  Epoch 83: iteration 214/215
# Epoch 83 --> loss:0.0456, acc:98.57%, val_loss:0.2564, val_acc:94.04%
#  Epoch 84: iteration 214/215
# Epoch 84 --> loss:0.0386, acc:98.74%, val_loss:0.2409, val_acc:95.09%
#  Epoch 85: iteration 214/215
# Epoch 85 --> loss:0.0394, acc:98.81%, val_loss:0.2310, val_acc:94.74%
#  Epoch 86: iteration 214/215
# Epoch 86 --> loss:0.0479, acc:98.57%, val_loss:0.2249, val_acc:95.44%
#  Epoch 87: iteration 214/215
# Epoch 87 --> loss:0.0928, acc:97.05%, val_loss:0.2540, val_acc:94.04%
#  Epoch 88: iteration 214/215
# Epoch 88 --> loss:0.0569, acc:98.33%, val_loss:0.2951, val_acc:94.39%
#  Epoch 89: iteration 214/215
# Epoch 89 --> loss:0.0658, acc:97.71%, val_loss:0.3195, val_acc:93.33%
#  Epoch 90: iteration 214/215
# Epoch 90 --> loss:0.0677, acc:97.91%, val_loss:0.2123, val_acc:96.49%
#  Epoch 91: iteration 214/215
# Epoch 91 --> loss:0.0638, acc:98.07%, val_loss:0.3264, val_acc:92.28%
#  Epoch 92: iteration 214/215
# Epoch 92 --> loss:0.0602, acc:98.26%, val_loss:0.2283, val_acc:94.74%
#  Epoch 93: iteration 214/215
# Epoch 93 --> loss:0.0762, acc:97.44%, val_loss:0.2602, val_acc:92.98%
#  Epoch 94: iteration 214/215
# Epoch 94 --> loss:0.0507, acc:98.41%, val_loss:0.2157, val_acc:94.74%
#  Epoch 95: iteration 214/215
# Epoch 95 --> loss:0.0521, acc:98.36%, val_loss:0.3112, val_acc:92.63%
#  Epoch 96: iteration 214/215
# Epoch 96 --> loss:0.0446, acc:98.71%, val_loss:0.2628, val_acc:94.39%
#  Epoch 97: iteration 214/215
# Epoch 97 --> loss:0.0454, acc:98.75%, val_loss:0.2343, val_acc:95.44%
#  Epoch 98: iteration 214/215
# Epoch 98 --> loss:0.0369, acc:98.97%, val_loss:0.2438, val_acc:94.74%
#  Epoch 99: iteration 214/215
# Epoch 99 --> loss:0.0686, acc:97.70%, val_loss:0.2161, val_acc:95.79%

# %% [markdown]
# # Save model

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_lstm_parallel_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_lstm_parallel_model.pt')))
# Out:
# Model is saved to /kaggle/working/models/cnn_lstm_parallel_model.pt

# %% [markdown]
# # Load model

# %%
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = ParallelModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_lstm_parallel_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_lstm_parallel_model.pt')))
# Out:
# Model is loaded from /kaggle/working/models/cnn_lstm_parallel_model.pt

# %% [markdown]
# # Test

# %%
import torch
import sklearn.metrics as metrics

X_test_tensor = torch.tensor(X_test, device=device).float()
Y_test_tensor = torch.tensor(Y_test, dtype=torch.long, device=device)
test_loss, test_acc, predictions = validate(X_test_tensor, Y_test_tensor)

if isinstance(predictions, torch.Tensor):
    predictions = predictions.cpu().numpy()

true_labels = Y_test_tensor.cpu().numpy()

recall = metrics.recall_score(true_labels, predictions, average='weighted')
f1 = metrics.f1_score(true_labels, predictions, average='weighted')

print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
print(f'Test recall is {recall:.2f}')
print(f'Test F1 score is {f1:.2f}')
# Out:
# Test loss is 0.157
# Test accuracy is 97.27%
# Test recall is 0.97
# Test F1 score is 0.97

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

predictions = predictions.cpu().numpy()
cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.show()

# %% [markdown]
# correlation between emotion intensity and corectness

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: 
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) 
plt.show()

# %% [markdown]
# correlation between gender and corectness

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: 
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16})
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])

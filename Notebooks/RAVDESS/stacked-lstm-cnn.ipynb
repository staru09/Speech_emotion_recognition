# %% [markdown]
# # Load file names

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'}
DATA_PATH = '/kaggle/input/ravdess-emotional-speech-audio'
SAMPLE_RATE = 48000

data = pd.DataFrame(columns=['Emotion', 'Emotion intensity', 'Gender', 'Path'])
for dirname, _, filenames in os.walk(DATA_PATH):
    for filename in filenames:
        file_path = os.path.join('/kaggle/input/', dirname, filename)
        identifiers = filename.split('.')[0].split('-')
        emotion = int(identifiers[2])
        if emotion == 8:
            emotion = 0
        emotion_intensity = 'normal' if int(identifiers[3]) == 1 else 'strong'
        gender = 'female' if int(identifiers[6]) % 2 == 0 else 'male'
        
        new_row = pd.DataFrame({
            "Emotion": [emotion],
            "Emotion intensity": [emotion_intensity],
            "Gender": [gender],
            "Path": [file_path]
        })
        data = pd.concat([data, new_row], ignore_index=True)

print(data)
# Out:
#      Emotion Emotion intensity  Gender  \
# 0          0            normal  female
# 1          1            normal  female
# 2          7            strong  female
# 3          7            normal  female
# 4          1            normal  female
# ...      ...               ...     ...
# 2875       6            normal    male
# 2876       5            normal    male
# 2877       4            strong    male
# 2878       7            strong    male
# 2879       5            strong    male
#
#                                                    Path
# 0     /kaggle/input/ravdess-emotional-speech-audio/A...
# 1     /kaggle/input/ravdess-emotional-speech-audio/A...
# 2     /kaggle/input/ravdess-emotional-speech-audio/A...
# 3     /kaggle/input/ravdess-emotional-speech-audio/A...
# 4     /kaggle/input/ravdess-emotional-speech-audio/A...
# ...                                                 ...
# 2875  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2876  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2877  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2878  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2879  /kaggle/input/ravdess-emotional-speech-audio/A...
#
# [2880 rows x 4 columns]

# %%
print("number of files is {}".format(len(data)))
data.head()
# Out:
# number of files is 2880
#   Emotion Emotion intensity  Gender  \
# 0       0            normal  female
# 1       1            normal  female
# 2       7            strong  female
# 3       7            normal  female
# 4       1            normal  female
#
#                                                 Path
# 0  /kaggle/input/ravdess-emotional-speech-audio/A...
# 1  /kaggle/input/ravdess-emotional-speech-audio/A...
# 2  /kaggle/input/ravdess-emotional-speech-audio/A...
# 3  /kaggle/input/ravdess-emotional-speech-audio/A...
# 4  /kaggle/input/ravdess-emotional-speech-audio/A...

# %% [markdown]
# number of examples per emotion

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(8), height=data['Emotion'].value_counts())
ax.set_xticks(ticks=range(8))
ax.set_xticklabels([EMOTIONS[i] for i in range(8)],fontsize=10)
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per gender

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Gender'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# number of examples per emotion intensity

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
counts = data['Emotion intensity'].value_counts()
ax.bar(x=[0,1], height=counts.values)
ax.set_xticks(ticks=[0,1])
ax.set_xticklabels(list(counts.index))
ax.set_xlabel('Gender')
ax.set_ylabel('Number of examples')
# Out:
# Text(0, 0.5, 'Number of examples')

# %% [markdown]
# # Load the signals

# %%
mel_spectrograms = []
signals = []
for i, file_path in enumerate(data.Path):
    audio, sample_rate = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE*3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\r Processed {}/{} files".format(i,len(data)),end='')
signals = np.stack(signals,axis=0)
# Out:
#  Processed 2879/2880 files

# %% [markdown]
# # Split the data

# %%
X = signals
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]
for emotion in range(len(EMOTIONS)):
    emotion_ind = list(data.loc[data.Emotion==emotion,'Emotion'].index)
    emotion_ind = np.random.permutation(emotion_ind)
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8*m)]
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    ind_test = emotion_ind[int(0.9*m):]
    X_train.append(X[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    X_val.append(X[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    X_test.append(X[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)
train_ind = np.concatenate(train_ind,0)
val_ind = np.concatenate(val_ind,0)
test_ind = np.concatenate(test_ind,0)
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# check if all are unique
unique, count = np.unique(np.concatenate([train_ind,test_ind,val_ind],0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count==1), X.shape[0]))

del X
# Out:
# X_train:(2302, 144000), Y_train:(2302,)
# X_val:(285, 144000), Y_val:(285,)
# X_test:(293, 144000), Y_test:(293,)
# Number of unique indexes is 2880, out of 2880

# %% [markdown]
# # Augment signals by adding AWGN

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
new_data_rows = []

for i in range(X_train.shape[0]):
    signal = X_train[i, :]
    augmented_signal = addAWGN(signal)
    
    if augmented_signal.shape != signal.shape:
        augmented_signal = augmented_signal[0, :]  

    aug_labels.append(Y_train[i]) 
    aug_signals.append(augmented_signal)
    
    new_row = data.iloc[i].copy()
    new_data_rows.append(new_row)
    
    print("\r Processed {}/{} files".format(i + 1, X_train.shape[0]), end='')

aug_signals = np.stack(aug_signals, axis=0)

#print(f"aug_signals shape: {aug_signals.shape}")

X_train = np.concatenate([X_train, aug_signals], axis=0)
aug_labels = np.array(aug_labels)
Y_train = np.concatenate([Y_train, aug_labels])

new_data_df = pd.DataFrame(new_data_rows)
data = pd.concat([data, new_data_df], ignore_index=True)

print('')
print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
# Out:
#  Processed 2302/2302 files
# X_train: (4604, 144000), Y_train: (4604,)

# %%
print(f"signal shape: {signal.shape}")
print(f"augmented_signal shape: {augmented_signal.shape}")
print(f"aug_signals shape: {aug_signals.shape}")
print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
# Out:
# signal shape: (144000,)
# augmented_signal shape: (144000,)
# aug_signals shape: (2302, 144000)
# X_train: (4604, 144000), Y_train: (4604,)

# %% [markdown]
# # Calculate mel spectrograms

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 563)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
del X_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
del X_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
del X_test
# Out:
# Calculatin mel spectrograms for train set
#  Processed 4603/4604 files
# Calculatin mel spectrograms for val set
#  Processed 284/285 files
# Calculatin mel spectrograms for test set
#  Processed 292/293 files

# %% [markdown]
# # Split into chunks

# %%
def splitIntoChunks(mel_spec,win_size,stride):
    t = mel_spec.shape[1]
    num_of_chunks = int(t/stride)
    chunks = []
    for i in range(num_of_chunks):
        chunk = mel_spec[:,i*stride:i*stride+win_size]
        if chunk.shape[1] == win_size:
            chunks.append(chunk)
    return np.stack(chunks,axis=0)

# %%
# get chunks
# train set
mel_train_chunked = []
for mel_spec in mel_train:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_train_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# val set
mel_val_chunked = []
for mel_spec in mel_val:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_val_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# test set
mel_test_chunked = []
for mel_spec in mel_test:
    chunks = splitIntoChunks(mel_spec, win_size=128,stride=64)
    mel_test_chunked.append(chunks)
print("Number of chunks is {}".format(chunks.shape[0]))
# Out:
# Number of chunks is 7
# Number of chunks is 7
# Number of chunks is 7

# %% [markdown]
# # Create the model

# %%
import torch
import torch.nn as nn
# BATCH FIRST TimeDistributed layer
class TimeDistributed(nn.Module):
    def __init__(self, module):
        super(TimeDistributed, self).__init__()
        self.module = module

    def forward(self, x):

        if len(x.size()) <= 2:
            return self.module(x)
        # squash samples and timesteps into a single axis
        elif len(x.size()) == 3: # (samples, timesteps, inp1)
            x_reshape = x.contiguous().view(-1, x.size(2))  # (samples * timesteps, inp1)
        elif len(x.size()) == 4: # (samples,timesteps,inp1,inp2)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3)) # (samples*timesteps,inp1,inp2)
        else: # (samples,timesteps,inp1,inp2,inp3)
            x_reshape = x.contiguous().view(-1, x.size(2), x.size(3),x.size(4)) # (samples*timesteps,inp1,inp2,inp3)
            
        y = self.module(x_reshape)
        
        # we have to reshape Y
        if len(x.size()) == 3:
            y = y.contiguous().view(x.size(0), -1, y.size(1))  # (samples, timesteps, out1)
        elif len(x.size()) == 4:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2)) # (samples, timesteps, out1,out2)
        else:
            y = y.contiguous().view(x.size(0), -1, y.size(1), y.size(2),y.size(3)) # (samples, timesteps, out1,out2, out3)
        return y

# %%
class HybridModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            TimeDistributed(nn.Conv2d(in_channels=1,
                                   out_channels=16,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(16)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=2, stride=2)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 2. conv block
            TimeDistributed(nn.Conv2d(in_channels=16,
                                   out_channels=32,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(32)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 3. conv block
            TimeDistributed(nn.Conv2d(in_channels=32,
                                   out_channels=64,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(64)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4)),
            # 4. conv block
            TimeDistributed(nn.Conv2d(in_channels=64,
                                   out_channels=128,
                                   kernel_size=3,
                                   stride=1,
                                   padding=1
                                  )),
            TimeDistributed(nn.BatchNorm2d(128)),
            TimeDistributed(nn.ReLU()),
            TimeDistributed(nn.MaxPool2d(kernel_size=4, stride=4)),
            TimeDistributed(nn.Dropout(p=0.4))
        )
        # LSTM block
        hidden_size = 64
        self.lstm = nn.LSTM(input_size=128,hidden_size=hidden_size,bidirectional=False, batch_first=True) 
        self.dropout_lstm = nn.Dropout(p=0.3)
        # Linear softmax layer
        self.out_linear = nn.Linear(hidden_size,num_emotions)
    def forward(self,x):
        conv_embedding = self.conv2Dblock(x)
        conv_embedding = torch.flatten(conv_embedding, start_dim=2) # do not flatten batch dimension and time
        lstm_embedding, (h,c) = self.lstm(conv_embedding)
        lstm_embedding = self.dropout_lstm(lstm_embedding)
        # lstm_embedding (batch, time, hidden_size)
        lstm_output = lstm_embedding[:,-1,:] 
        output_logits = self.out_linear(lstm_output)
        output_softmax = nn.functional.softmax(output_logits,dim=1)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %% [markdown]
# # TRAINING

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %% [markdown]
# stack data

# %%
X_train = np.stack(mel_train_chunked,axis=0)
X_train = np.expand_dims(X_train,2)
print('Shape of X_train: ',X_train.shape)
X_val = np.stack(mel_val_chunked,axis=0)
X_val = np.expand_dims(X_val,2)
print('Shape of X_val: ',X_val.shape)
X_test = np.stack(mel_test_chunked,axis=0)
X_test = np.expand_dims(X_test,2)
print('Shape of X_test: ',X_test.shape)

del mel_train_chunked
del mel_train
del mel_val_chunked
del mel_val
del mel_test_chunked
del mel_test
# Out:
# Shape of X_train:  (4604, 7, 1, 128, 128)
# Shape of X_val:  (285, 7, 1, 128, 128)
# Shape of X_test:  (293, 7, 1, 128, 128)

# %% [markdown]
# scale data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

b,t,c,h,w = X_train.shape
X_train = np.reshape(X_train, newshape=(b,-1))
X_train = scaler.fit_transform(X_train)
X_train = np.reshape(X_train, newshape=(b,t,c,h,w))

b,t,c,h,w = X_test.shape
X_test = np.reshape(X_test, newshape=(b,-1))
X_test = scaler.transform(X_test)
X_test = np.reshape(X_test, newshape=(b,t,c,h,w))

b,t,c,h,w = X_val.shape
X_val = np.reshape(X_val, newshape=(b,-1))
X_val = scaler.transform(X_val)
X_val = np.reshape(X_val, newshape=(b,t,c,h,w))

# %% [markdown]
# train the model

# %%
EPOCHS=200
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = HybridModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()))
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  147816
#  Epoch 0: iteration 142/143
# Epoch 0 --> loss:2.0589, acc:13.58%, val_loss:2.0695, val_acc:14.74%
#  Epoch 1: iteration 142/143
# Epoch 1 --> loss:2.0172, acc:17.70%, val_loss:2.1102, val_acc:17.19%
#  Epoch 2: iteration 142/143
# Epoch 2 --> loss:1.9723, acc:20.66%, val_loss:2.1617, val_acc:13.33%
#  Epoch 3: iteration 142/143
# Epoch 3 --> loss:1.9437, acc:22.00%, val_loss:2.1450, val_acc:14.74%
#  Epoch 4: iteration 142/143
# Epoch 4 --> loss:1.9073, acc:24.65%, val_loss:2.1090, val_acc:17.89%
#  Epoch 5: iteration 142/143
# Epoch 5 --> loss:1.8415, acc:27.15%, val_loss:2.1210, val_acc:22.81%
#  Epoch 6: iteration 142/143
# Epoch 6 --> loss:1.7973, acc:29.93%, val_loss:2.0608, val_acc:21.75%
#  Epoch 7: iteration 142/143
# Epoch 7 --> loss:1.7492, acc:31.36%, val_loss:2.0015, val_acc:24.91%
#  Epoch 8: iteration 142/143
# Epoch 8 --> loss:1.7264, acc:32.75%, val_loss:1.9675, val_acc:24.21%
#  Epoch 9: iteration 142/143
# Epoch 9 --> loss:1.7009, acc:33.88%, val_loss:2.0098, val_acc:19.65%
#  Epoch 10: iteration 142/143
# Epoch 10 --> loss:1.6936, acc:33.60%, val_loss:1.8759, val_acc:23.51%
#  Epoch 11: iteration 142/143
# Epoch 11 --> loss:1.6718, acc:34.77%, val_loss:2.0840, val_acc:18.60%
#  Epoch 12: iteration 142/143
# Epoch 12 --> loss:1.6377, acc:36.73%, val_loss:1.9612, val_acc:21.40%
#  Epoch 13: iteration 142/143
# Epoch 13 --> loss:1.6099, acc:37.75%, val_loss:1.8763, val_acc:26.32%
#  Epoch 14: iteration 142/143
# Epoch 14 --> loss:1.6045, acc:38.18%, val_loss:1.9187, val_acc:25.26%
#  Epoch 15: iteration 142/143
# Epoch 15 --> loss:1.5799, acc:39.57%, val_loss:1.8739, val_acc:24.56%
#  Epoch 16: iteration 142/143
# Epoch 16 --> loss:1.5675, acc:38.88%, val_loss:1.9642, val_acc:23.86%
#  Epoch 17: iteration 142/143
# Epoch 17 --> loss:1.5286, acc:40.75%, val_loss:1.7780, val_acc:30.18%
#  Epoch 18: iteration 142/143
# Epoch 18 --> loss:1.5168, acc:41.62%, val_loss:1.7261, val_acc:32.63%
#  Epoch 19: iteration 142/143
# Epoch 19 --> loss:1.5099, acc:41.90%, val_loss:1.6053, val_acc:41.40%
#  Epoch 20: iteration 142/143
# Epoch 20 --> loss:1.4691, acc:43.29%, val_loss:1.9534, val_acc:27.02%
#  Epoch 21: iteration 142/143
# Epoch 21 --> loss:1.4459, acc:44.27%, val_loss:1.9641, val_acc:26.67%
#  Epoch 22: iteration 142/143
# Epoch 22 --> loss:1.4272, acc:45.37%, val_loss:1.4518, val_acc:47.72%
#  Epoch 23: iteration 142/143
# Epoch 23 --> loss:1.4149, acc:45.44%, val_loss:1.4883, val_acc:43.51%
#  Epoch 24: iteration 142/143
# Epoch 24 --> loss:1.3899, acc:46.35%, val_loss:1.4549, val_acc:44.21%
#  Epoch 25: iteration 142/143
# Epoch 25 --> loss:1.3748, acc:46.37%, val_loss:1.5306, val_acc:43.16%
#  Epoch 26: iteration 142/143
# Epoch 26 --> loss:1.3566, acc:47.76%, val_loss:1.6968, val_acc:36.14%
#  Epoch 27: iteration 142/143
# Epoch 27 --> loss:1.3555, acc:47.91%, val_loss:1.4257, val_acc:46.32%
#  Epoch 28: iteration 142/143
# Epoch 28 --> loss:1.3434, acc:48.02%, val_loss:1.3166, val_acc:51.58%
#  Epoch 29: iteration 142/143
# Epoch 29 --> loss:1.3245, acc:49.50%, val_loss:1.5863, val_acc:39.65%
#  Epoch 30: iteration 142/143
# Epoch 30 --> loss:1.2984, acc:50.87%, val_loss:1.4160, val_acc:48.07%
#  Epoch 31: iteration 142/143
# Epoch 31 --> loss:1.3022, acc:50.56%, val_loss:1.5548, val_acc:41.75%
#  Epoch 32: iteration 142/143
# Epoch 32 --> loss:1.2672, acc:51.72%, val_loss:1.3025, val_acc:49.12%
#  Epoch 33: iteration 142/143
# Epoch 33 --> loss:1.2729, acc:51.50%, val_loss:1.3620, val_acc:47.72%
#  Epoch 34: iteration 142/143
# Epoch 34 --> loss:1.2487, acc:52.37%, val_loss:1.3536, val_acc:48.07%
#  Epoch 35: iteration 142/143
# Epoch 35 --> loss:1.2360, acc:52.80%, val_loss:1.3780, val_acc:48.42%
#  Epoch 36: iteration 142/143
# Epoch 36 --> loss:1.2111, acc:53.17%, val_loss:1.2767, val_acc:50.88%
#  Epoch 37: iteration 142/143
# Epoch 37 --> loss:1.2223, acc:52.93%, val_loss:1.3682, val_acc:43.16%
#  Epoch 38: iteration 142/143
# Epoch 38 --> loss:1.1930, acc:54.54%, val_loss:1.3623, val_acc:48.07%
#  Epoch 39: iteration 142/143
# Epoch 39 --> loss:1.1782, acc:54.67%, val_loss:1.3552, val_acc:50.53%
#  Epoch 40: iteration 142/143
# Epoch 40 --> loss:1.1694, acc:55.30%, val_loss:1.2944, val_acc:54.74%
#  Epoch 41: iteration 142/143
# Epoch 41 --> loss:1.1373, acc:56.73%, val_loss:1.2386, val_acc:52.63%
#  Epoch 42: iteration 142/143
# Epoch 42 --> loss:1.1270, acc:56.65%, val_loss:1.3118, val_acc:50.53%
#  Epoch 43: iteration 142/143
# Epoch 43 --> loss:1.1169, acc:57.17%, val_loss:1.2256, val_acc:52.98%
#  Epoch 44: iteration 142/143
# Epoch 44 --> loss:1.1027, acc:57.52%, val_loss:1.0777, val_acc:60.70%
#  Epoch 45: iteration 142/143
# Epoch 45 --> loss:1.0930, acc:57.93%, val_loss:1.1022, val_acc:58.25%
#  Epoch 46: iteration 142/143
# Epoch 46 --> loss:1.0626, acc:59.82%, val_loss:1.0689, val_acc:60.00%
#  Epoch 47: iteration 142/143
# Epoch 47 --> loss:1.0606, acc:59.47%, val_loss:1.2426, val_acc:51.93%
#  Epoch 48: iteration 142/143
# Epoch 48 --> loss:1.0498, acc:59.49%, val_loss:1.1296, val_acc:55.79%
#  Epoch 49: iteration 142/143
# Epoch 49 --> loss:1.0236, acc:61.10%, val_loss:1.1053, val_acc:60.35%
#  Epoch 50: iteration 142/143
# Epoch 50 --> loss:1.0085, acc:61.06%, val_loss:1.5381, val_acc:44.56%
#  Epoch 51: iteration 142/143
# Epoch 51 --> loss:0.9953, acc:61.53%, val_loss:1.4194, val_acc:43.16%
#  Epoch 52: iteration 142/143
# Epoch 52 --> loss:0.9815, acc:62.38%, val_loss:1.0722, val_acc:58.95%
#  Epoch 53: iteration 142/143
# Epoch 53 --> loss:0.9738, acc:62.90%, val_loss:1.4556, val_acc:44.91%
#  Epoch 54: iteration 142/143
# Epoch 54 --> loss:0.9405, acc:64.57%, val_loss:1.0280, val_acc:64.91%
#  Epoch 55: iteration 142/143
# Epoch 55 --> loss:0.9153, acc:65.96%, val_loss:1.0727, val_acc:58.60%
#  Epoch 56: iteration 142/143
# Epoch 56 --> loss:0.9136, acc:65.53%, val_loss:1.1714, val_acc:54.74%
#  Epoch 57: iteration 142/143
# Epoch 57 --> loss:0.8813, acc:66.18%, val_loss:1.0023, val_acc:62.46%
#  Epoch 58: iteration 142/143
# Epoch 58 --> loss:0.8741, acc:66.68%, val_loss:1.1220, val_acc:57.19%
#  Epoch 59: iteration 142/143
# Epoch 59 --> loss:0.8476, acc:68.07%, val_loss:1.0657, val_acc:60.00%
#  Epoch 60: iteration 142/143
# Epoch 60 --> loss:0.8394, acc:68.03%, val_loss:1.0634, val_acc:63.16%
#  Epoch 61: iteration 142/143
# Epoch 61 --> loss:0.8235, acc:68.64%, val_loss:0.9785, val_acc:65.96%
#  Epoch 62: iteration 142/143
# Epoch 62 --> loss:0.8047, acc:69.77%, val_loss:1.0282, val_acc:60.35%
#  Epoch 63: iteration 142/143
# Epoch 63 --> loss:0.7972, acc:70.09%, val_loss:1.3655, val_acc:49.82%
#  Epoch 64: iteration 142/143
# Epoch 64 --> loss:0.7653, acc:70.85%, val_loss:1.0269, val_acc:59.65%
#  Epoch 65: iteration 142/143
# Epoch 65 --> loss:0.7531, acc:72.22%, val_loss:1.0176, val_acc:58.95%
#  Epoch 66: iteration 142/143
# Epoch 66 --> loss:0.7392, acc:72.52%, val_loss:1.1764, val_acc:54.74%
#  Epoch 67: iteration 142/143
# Epoch 67 --> loss:0.7395, acc:72.18%, val_loss:1.0512, val_acc:63.16%
#  Epoch 68: iteration 142/143
# Epoch 68 --> loss:0.7355, acc:72.87%, val_loss:1.2831, val_acc:48.42%
#  Epoch 69: iteration 142/143
# Epoch 69 --> loss:0.7080, acc:73.54%, val_loss:1.0287, val_acc:62.46%
#  Epoch 70: iteration 142/143
# Epoch 70 --> loss:0.7180, acc:72.48%, val_loss:0.8731, val_acc:69.82%
#  Epoch 71: iteration 142/143
# Epoch 71 --> loss:0.6911, acc:74.26%, val_loss:0.9881, val_acc:65.96%
#  Epoch 72: iteration 142/143
# Epoch 72 --> loss:0.6567, acc:75.89%, val_loss:0.6887, val_acc:76.49%
#  Epoch 73: iteration 142/143
# Epoch 73 --> loss:0.6625, acc:75.48%, val_loss:1.1042, val_acc:57.54%
#  Epoch 74: iteration 142/143
# Epoch 74 --> loss:0.6458, acc:76.37%, val_loss:1.0177, val_acc:62.46%
#  Epoch 75: iteration 142/143
# Epoch 75 --> loss:0.6460, acc:75.28%, val_loss:0.7599, val_acc:74.04%
#  Epoch 76: iteration 142/143
# Epoch 76 --> loss:0.6445, acc:75.93%, val_loss:0.9379, val_acc:63.86%
#  Epoch 77: iteration 142/143
# Epoch 77 --> loss:0.6229, acc:76.91%, val_loss:0.7998, val_acc:70.18%
#  Epoch 78: iteration 142/143
# Epoch 78 --> loss:0.5998, acc:77.89%, val_loss:0.7159, val_acc:75.44%
#  Epoch 79: iteration 142/143
# Epoch 79 --> loss:0.6295, acc:76.98%, val_loss:0.8772, val_acc:68.77%
#  Epoch 80: iteration 142/143
# Epoch 80 --> loss:0.5893, acc:77.56%, val_loss:1.0607, val_acc:62.11%
#  Epoch 81: iteration 142/143
# Epoch 81 --> loss:0.6057, acc:77.37%, val_loss:0.7904, val_acc:70.18%
#  Epoch 82: iteration 142/143
# Epoch 82 --> loss:0.5692, acc:78.93%, val_loss:0.7726, val_acc:75.79%
#  Epoch 83: iteration 142/143
# Epoch 83 --> loss:0.5771, acc:78.39%, val_loss:0.7919, val_acc:71.58%
#  Epoch 84: iteration 142/143
# Epoch 84 --> loss:0.5582, acc:79.08%, val_loss:0.6764, val_acc:80.35%
#  Epoch 85: iteration 142/143
# Epoch 85 --> loss:0.5448, acc:80.28%, val_loss:0.7581, val_acc:74.39%
#  Epoch 86: iteration 142/143
# Epoch 86 --> loss:0.5500, acc:79.93%, val_loss:1.0000, val_acc:64.91%
#  Epoch 87: iteration 142/143
# Epoch 87 --> loss:0.5498, acc:79.65%, val_loss:1.0340, val_acc:63.51%
#  Epoch 88: iteration 142/143
# Epoch 88 --> loss:0.5280, acc:80.19%, val_loss:0.6559, val_acc:77.54%
#  Epoch 89: iteration 142/143
# Epoch 89 --> loss:0.5278, acc:80.76%, val_loss:0.6099, val_acc:81.75%
#  Epoch 90: iteration 142/143
# Epoch 90 --> loss:0.5296, acc:80.36%, val_loss:0.6826, val_acc:78.25%
#  Epoch 91: iteration 142/143
# Epoch 91 --> loss:0.5116, acc:80.86%, val_loss:0.7004, val_acc:76.14%
#  Epoch 92: iteration 142/143
# Epoch 92 --> loss:0.5425, acc:80.71%, val_loss:0.7107, val_acc:76.84%
#  Epoch 93: iteration 142/143
# Epoch 93 --> loss:0.4962, acc:81.76%, val_loss:0.8418, val_acc:70.53%
#  Epoch 94: iteration 142/143
# Epoch 94 --> loss:0.4968, acc:81.52%, val_loss:0.5600, val_acc:80.70%
#  Epoch 95: iteration 142/143
# Epoch 95 --> loss:0.4926, acc:81.99%, val_loss:0.6409, val_acc:78.60%
#  Epoch 96: iteration 142/143
# Epoch 96 --> loss:0.5137, acc:81.32%, val_loss:0.6292, val_acc:78.60%
#  Epoch 97: iteration 142/143
# Epoch 97 --> loss:0.4765, acc:81.91%, val_loss:0.7859, val_acc:73.68%
#  Epoch 98: iteration 142/143
# Epoch 98 --> loss:0.4975, acc:82.06%, val_loss:0.5973, val_acc:81.75%
#  Epoch 99: iteration 142/143
# Epoch 99 --> loss:0.4832, acc:82.47%, val_loss:0.5858, val_acc:78.95%
#  Epoch 100: iteration 142/143
# Epoch 100 --> loss:0.4626, acc:83.67%, val_loss:0.7399, val_acc:71.23%
#  Epoch 101: iteration 142/143
# Epoch 101 --> loss:0.4702, acc:82.43%, val_loss:0.5954, val_acc:82.11%
#  Epoch 102: iteration 142/143
# Epoch 102 --> loss:0.4511, acc:83.10%, val_loss:0.6353, val_acc:78.95%
#  Epoch 103: iteration 142/143
# Epoch 103 --> loss:0.4641, acc:82.36%, val_loss:0.9078, val_acc:67.37%
#  Epoch 104: iteration 142/143
# Epoch 104 --> loss:0.4620, acc:83.38%, val_loss:0.4867, val_acc:85.61%
#  Epoch 105: iteration 142/143
# Epoch 105 --> loss:0.4435, acc:84.12%, val_loss:0.7235, val_acc:75.79%
#  Epoch 106: iteration 142/143
# Epoch 106 --> loss:0.4404, acc:83.78%, val_loss:0.7693, val_acc:71.23%
#  Epoch 107: iteration 142/143
# Epoch 107 --> loss:0.4632, acc:82.84%, val_loss:0.7429, val_acc:73.33%
#  Epoch 108: iteration 142/143
# Epoch 108 --> loss:0.4328, acc:84.17%, val_loss:0.6022, val_acc:80.70%
#  Epoch 109: iteration 142/143
# Epoch 109 --> loss:0.4332, acc:84.08%, val_loss:0.7448, val_acc:72.63%
#  Epoch 110: iteration 142/143
# Epoch 110 --> loss:0.4343, acc:84.10%, val_loss:0.5974, val_acc:79.65%
#  Epoch 111: iteration 142/143
# Epoch 111 --> loss:0.4060, acc:85.08%, val_loss:0.8560, val_acc:69.82%
#  Epoch 112: iteration 142/143
# Epoch 112 --> loss:0.4166, acc:85.12%, val_loss:0.5399, val_acc:81.05%
#  Epoch 113: iteration 142/143
# Epoch 113 --> loss:0.4191, acc:84.67%, val_loss:0.4738, val_acc:85.61%
#  Epoch 114: iteration 142/143
# Epoch 114 --> loss:0.3993, acc:84.93%, val_loss:0.5759, val_acc:81.75%
#  Epoch 115: iteration 142/143
# Epoch 115 --> loss:0.4143, acc:85.12%, val_loss:0.5919, val_acc:77.54%
#  Epoch 116: iteration 142/143
# Epoch 116 --> loss:0.4172, acc:85.12%, val_loss:0.5069, val_acc:85.61%
#  Epoch 117: iteration 142/143
# Epoch 117 --> loss:0.4071, acc:85.86%, val_loss:0.4824, val_acc:83.51%
#  Epoch 118: iteration 142/143
# Epoch 118 --> loss:0.4008, acc:85.38%, val_loss:0.4825, val_acc:86.32%
#  Epoch 119: iteration 142/143
# Epoch 119 --> loss:0.3815, acc:86.01%, val_loss:0.4455, val_acc:86.32%
#  Epoch 120: iteration 142/143
# Epoch 120 --> loss:0.3979, acc:85.79%, val_loss:0.6265, val_acc:78.60%
#  Epoch 121: iteration 142/143
# Epoch 121 --> loss:0.3971, acc:85.27%, val_loss:0.5984, val_acc:77.89%
#  Epoch 122: iteration 142/143
# Epoch 122 --> loss:0.3679, acc:86.86%, val_loss:0.7802, val_acc:71.58%
#  Epoch 123: iteration 142/143
# Epoch 123 --> loss:0.3765, acc:86.08%, val_loss:0.5169, val_acc:82.81%
#  Epoch 124: iteration 142/143
# Epoch 124 --> loss:0.3940, acc:85.62%, val_loss:0.5734, val_acc:80.00%
#  Epoch 125: iteration 142/143
# Epoch 125 --> loss:0.3655, acc:86.16%, val_loss:0.6351, val_acc:77.19%
#  Epoch 126: iteration 142/143
# Epoch 126 --> loss:0.3747, acc:86.38%, val_loss:0.4150, val_acc:86.67%
#  Epoch 127: iteration 142/143
# Epoch 127 --> loss:0.3674, acc:86.95%, val_loss:0.4210, val_acc:88.07%
#  Epoch 128: iteration 142/143
# Epoch 128 --> loss:0.3951, acc:85.75%, val_loss:0.5401, val_acc:80.70%
#  Epoch 129: iteration 142/143
# Epoch 129 --> loss:0.4036, acc:85.14%, val_loss:0.8311, val_acc:67.37%
#  Epoch 130: iteration 142/143
# Epoch 130 --> loss:0.3656, acc:86.49%, val_loss:0.5041, val_acc:83.86%
#  Epoch 131: iteration 142/143
# Epoch 131 --> loss:0.3403, acc:87.47%, val_loss:0.5727, val_acc:81.05%
#  Epoch 132: iteration 142/143
# Epoch 132 --> loss:0.3529, acc:86.95%, val_loss:0.4905, val_acc:82.81%
#  Epoch 133: iteration 142/143
# Epoch 133 --> loss:0.3771, acc:85.86%, val_loss:0.4577, val_acc:86.67%
#  Epoch 134: iteration 142/143
# Epoch 134 --> loss:0.3665, acc:87.03%, val_loss:0.8151, val_acc:69.82%
#  Epoch 135: iteration 142/143
# Epoch 135 --> loss:0.3598, acc:86.69%, val_loss:0.5225, val_acc:82.81%
#  Epoch 136: iteration 142/143
# Epoch 136 --> loss:0.3625, acc:86.36%, val_loss:0.4868, val_acc:84.21%
#  Epoch 137: iteration 142/143
# Epoch 137 --> loss:0.3797, acc:85.88%, val_loss:0.4164, val_acc:87.02%
#  Epoch 138: iteration 142/143
# Epoch 138 --> loss:0.3477, acc:87.19%, val_loss:0.5328, val_acc:80.00%
#  Epoch 139: iteration 142/143
# Epoch 139 --> loss:0.3633, acc:86.51%, val_loss:0.5360, val_acc:82.46%
#  Epoch 140: iteration 142/143
# Epoch 140 --> loss:0.3412, acc:87.75%, val_loss:0.4702, val_acc:83.51%
#  Epoch 141: iteration 142/143
# Epoch 141 --> loss:0.3435, acc:87.81%, val_loss:0.4526, val_acc:85.61%
#  Epoch 142: iteration 142/143
# Epoch 142 --> loss:0.3537, acc:86.97%, val_loss:0.6076, val_acc:78.25%
#  Epoch 143: iteration 142/143
# Epoch 143 --> loss:0.3340, acc:87.51%, val_loss:0.4568, val_acc:85.61%
#  Epoch 144: iteration 142/143
# Epoch 144 --> loss:0.3519, acc:86.84%, val_loss:0.6968, val_acc:74.04%
#  Epoch 145: iteration 142/143
# Epoch 145 --> loss:0.3491, acc:87.58%, val_loss:0.5059, val_acc:81.05%
#  Epoch 146: iteration 142/143
# Epoch 146 --> loss:0.3214, acc:88.44%, val_loss:0.6480, val_acc:79.30%
#  Epoch 147: iteration 142/143
# Epoch 147 --> loss:0.3312, acc:88.18%, val_loss:0.3530, val_acc:90.18%
#  Epoch 148: iteration 142/143
# Epoch 148 --> loss:0.3382, acc:87.97%, val_loss:0.7809, val_acc:72.28%
#  Epoch 149: iteration 142/143
# Epoch 149 --> loss:0.3362, acc:87.90%, val_loss:0.3919, val_acc:86.67%
#  Epoch 150: iteration 142/143
# Epoch 150 --> loss:0.3443, acc:87.42%, val_loss:0.4108, val_acc:87.02%
#  Epoch 151: iteration 142/143
# Epoch 151 --> loss:0.3472, acc:87.03%, val_loss:0.4711, val_acc:85.96%
#  Epoch 152: iteration 142/143
# Epoch 152 --> loss:0.3360, acc:86.99%, val_loss:0.4068, val_acc:87.72%
#  Epoch 153: iteration 142/143
# Epoch 153 --> loss:0.3359, acc:87.14%, val_loss:0.4835, val_acc:80.00%
#  Epoch 154: iteration 142/143
# Epoch 154 --> loss:0.3468, acc:87.25%, val_loss:0.5662, val_acc:81.75%
#  Epoch 155: iteration 142/143
# Epoch 155 --> loss:0.3287, acc:87.79%, val_loss:0.3229, val_acc:88.77%
#  Epoch 156: iteration 142/143
# Epoch 156 --> loss:0.3244, acc:88.81%, val_loss:0.4713, val_acc:84.21%
#  Epoch 157: iteration 142/143
# Epoch 157 --> loss:0.3470, acc:87.21%, val_loss:0.3501, val_acc:90.88%
#  Epoch 158: iteration 142/143
# Epoch 158 --> loss:0.3068, acc:88.66%, val_loss:0.3495, val_acc:90.18%
#  Epoch 159: iteration 142/143
# Epoch 159 --> loss:0.3100, acc:88.42%, val_loss:0.4639, val_acc:81.75%
#  Epoch 160: iteration 142/143
# Epoch 160 --> loss:0.3287, acc:88.36%, val_loss:0.4741, val_acc:82.11%
#  Epoch 161: iteration 142/143
# Epoch 161 --> loss:0.3401, acc:87.68%, val_loss:0.5512, val_acc:80.70%
#  Epoch 162: iteration 142/143
# Epoch 162 --> loss:0.3163, acc:88.29%, val_loss:0.4228, val_acc:84.91%
#  Epoch 163: iteration 142/143
# Epoch 163 --> loss:0.3167, acc:88.77%, val_loss:0.5743, val_acc:76.14%
#  Epoch 164: iteration 142/143
# Epoch 164 --> loss:0.2996, acc:89.12%, val_loss:0.4099, val_acc:85.96%
#  Epoch 165: iteration 142/143
# Epoch 165 --> loss:0.2996, acc:89.14%, val_loss:0.4799, val_acc:83.51%
#  Epoch 166: iteration 142/143
# Epoch 166 --> loss:0.3114, acc:88.62%, val_loss:0.4365, val_acc:86.32%
#  Epoch 167: iteration 142/143
# Epoch 167 --> loss:0.3122, acc:88.94%, val_loss:0.5319, val_acc:81.75%
#  Epoch 168: iteration 142/143
# Epoch 168 --> loss:0.3007, acc:88.97%, val_loss:0.7385, val_acc:75.09%
#  Epoch 169: iteration 142/143
# Epoch 169 --> loss:0.3101, acc:88.97%, val_loss:0.2872, val_acc:91.58%
#  Epoch 170: iteration 142/143
# Epoch 170 --> loss:0.2907, acc:89.18%, val_loss:0.4784, val_acc:82.81%
#  Epoch 171: iteration 142/143
# Epoch 171 --> loss:0.3029, acc:89.14%, val_loss:0.5223, val_acc:81.05%
#  Epoch 172: iteration 142/143
# Epoch 172 --> loss:0.3097, acc:88.53%, val_loss:0.4084, val_acc:85.61%
#  Epoch 173: iteration 142/143
# Epoch 173 --> loss:0.2906, acc:89.27%, val_loss:0.5692, val_acc:78.95%
#  Epoch 174: iteration 142/143
# Epoch 174 --> loss:0.2882, acc:89.14%, val_loss:0.4143, val_acc:85.61%
#  Epoch 175: iteration 142/143
# Epoch 175 --> loss:0.3002, acc:89.47%, val_loss:0.6637, val_acc:76.49%
#  Epoch 176: iteration 142/143
# Epoch 176 --> loss:0.2933, acc:89.01%, val_loss:0.3660, val_acc:86.32%
#  Epoch 177: iteration 142/143
# Epoch 177 --> loss:0.2921, acc:89.31%, val_loss:0.3537, val_acc:88.77%
#  Epoch 178: iteration 142/143
# Epoch 178 --> loss:0.3160, acc:88.31%, val_loss:0.6560, val_acc:76.14%
#  Epoch 179: iteration 142/143
# Epoch 179 --> loss:0.2942, acc:89.12%, val_loss:0.4058, val_acc:86.32%
#  Epoch 180: iteration 142/143
# Epoch 180 --> loss:0.3035, acc:88.97%, val_loss:0.4181, val_acc:85.96%
#  Epoch 181: iteration 142/143
# Epoch 181 --> loss:0.3122, acc:88.10%, val_loss:0.3617, val_acc:88.07%
#  Epoch 182: iteration 142/143
# Epoch 182 --> loss:0.2888, acc:89.77%, val_loss:0.3355, val_acc:90.88%
#  Epoch 183: iteration 142/143
# Epoch 183 --> loss:0.2829, acc:89.73%, val_loss:0.3737, val_acc:87.37%
#  Epoch 184: iteration 142/143
# Epoch 184 --> loss:0.2704, acc:89.92%, val_loss:0.5016, val_acc:80.70%
#  Epoch 185: iteration 142/143
# Epoch 185 --> loss:0.2956, acc:88.97%, val_loss:0.4201, val_acc:86.67%
#  Epoch 186: iteration 142/143
# Epoch 186 --> loss:0.2983, acc:88.99%, val_loss:0.3850, val_acc:88.42%
#  Epoch 187: iteration 142/143
# Epoch 187 --> loss:0.2816, acc:89.81%, val_loss:0.4942, val_acc:83.16%
#  Epoch 188: iteration 142/143
# Epoch 188 --> loss:0.2913, acc:89.36%, val_loss:0.5387, val_acc:81.40%
#  Epoch 189: iteration 142/143
# Epoch 189 --> loss:0.2953, acc:89.07%, val_loss:0.5084, val_acc:81.75%
#  Epoch 190: iteration 142/143
# Epoch 190 --> loss:0.2727, acc:90.23%, val_loss:0.5444, val_acc:81.05%
#  Epoch 191: iteration 142/143
# Epoch 191 --> loss:0.2845, acc:89.36%, val_loss:0.2983, val_acc:90.53%
#  Epoch 192: iteration 142/143
# Epoch 192 --> loss:0.2723, acc:90.14%, val_loss:0.4672, val_acc:83.51%
#  Epoch 193: iteration 142/143
# Epoch 193 --> loss:0.2812, acc:89.90%, val_loss:0.4158, val_acc:86.67%
#  Epoch 194: iteration 142/143
# Epoch 194 --> loss:0.2805, acc:89.62%, val_loss:0.4040, val_acc:85.26%
#  Epoch 195: iteration 142/143
# Epoch 195 --> loss:0.2831, acc:89.62%, val_loss:0.4063, val_acc:88.77%
#  Epoch 196: iteration 142/143
# Epoch 196 --> loss:0.2846, acc:89.99%, val_loss:0.3736, val_acc:88.77%
#  Epoch 197: iteration 142/143
# Epoch 197 --> loss:0.2815, acc:89.94%, val_loss:0.3427, val_acc:90.18%
#  Epoch 198: iteration 142/143
# Epoch 198 --> loss:0.2917, acc:89.12%, val_loss:0.3237, val_acc:90.18%
#  Epoch 199: iteration 142/143
# Epoch 199 --> loss:0.2704, acc:90.20%, val_loss:0.3051, val_acc:89.47%

# %% [markdown]
# # Save model

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_attention_lstm_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_attention_lstm_model.pt')))
# Out:
# Model is saved to /kaggle/working/models/cnn_attention_lstm_model.pt

# %% [markdown]
# # Load model

# %%
LOAD_PATH = os.path.join(os.getcwd(),'models')
model = HybridModel(len(EMOTIONS))
model.load_state_dict(torch.load(os.path.join(LOAD_PATH,'cnn_attention_lstm_model.pt')))
print('Model is loaded from {}'.format(os.path.join(LOAD_PATH,'cnn_attention_lstm_model.pt')))
# Out:
# Model is loaded from /kaggle/working/models/cnn_attention_lstm_model.pt

# %% [markdown]
# # Test

# %%
import sklearn.metrics as metrics

X_test_tensor = torch.tensor(X_test, device=device).float()
Y_test_tensor = torch.tensor(Y_test, dtype=torch.long, device=device)
test_loss, test_acc, predictions = validate(X_test_tensor, Y_test_tensor)

predictions = predictions.cpu().numpy()
true_labels = Y_test_tensor.cpu().numpy()

recall = metrics.recall_score(true_labels, predictions, average='weighted')
f1 = metrics.f1_score(true_labels, predictions, average='weighted')

print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
print(f'Test recall is {recall:.2f}')
print(f'Test F1 score is {f1:.2f}')
# Out:
# Test loss is 0.809
# Test accuracy is 68.60%
# Test recall is 0.69
# Test F1 score is 0.68

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

# Ensure predictions is a numpy array
if not isinstance(predictions, np.ndarray):
    predictions = predictions.cpu().numpy()

cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)
sn.set(font_scale=1.4)  # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})  # font size
plt.show()

# %% [markdown]
# Correlation between emotion intensity and correct prediction

# %%
correct_strong = 0
correct_normal = 0
wrong_strong = 0
wrong_normal = 0
for i in range(len(X_test)):
    intensity = data.loc[test_ind[i],'Emotion intensity']
    if Y_test[i] == predictions[i]: # correct prediction
        if  intensity == 'normal':
            correct_normal += 1
        else:
            correct_strong += 1
    else: # wrong prediction
        if intensity == 'normal':
            wrong_normal += 1
        else:
            wrong_strong += 1
array = np.array([[wrong_normal,wrong_strong],[correct_normal,correct_strong]])
df = pd.DataFrame(array,['wrong','correct'],['normal','strong'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# correlation between gender and corectness

# %%
correct_male = 0
correct_female = 0
wrong_male = 0
wrong_female = 0
for i in range(len(X_test)):
    gender = data.loc[test_ind[i],'Gender']
    if Y_test[i] == predictions[i]: # correct prediction
        if  gender == 'male':
            correct_male += 1
        else:
            correct_female += 1
    else: # wrong prediction
        if gender == 'male':
            wrong_male += 1
        else:
            wrong_female += 1
array = np.array([[wrong_male,wrong_female],[correct_male,correct_female]])
df = pd.DataFrame(array,['wrong','correct'],['male','female'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(df, annot=True, annot_kws={"size": 16}) # font size
plt.show()

# %% [markdown]
# # Plot loss

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])

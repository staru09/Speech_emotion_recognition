# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

import os
import sys

import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

from IPython.display import Audio

import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import os
import pandas as pd

PATH = '/kaggle/input/indian-emotion/Audio Mode Only/'
file_emotion = []
file_path = []

emotions = ['Anger', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad']

for emotion in emotions:
    emotion_folder = os.path.join(PATH, emotion)
    print(f"Checking folder: {emotion_folder}") 
    
    if os.path.isdir(emotion_folder):
        for file in os.listdir(emotion_folder):
            file_full_path = os.path.join(emotion_folder, file)
            #print(f"Found file: {file_full_path}") 
            file_path.append(file_full_path)
            file_emotion.append(emotion.lower())
    else:
        print(f"Folder not found: {emotion_folder}")

emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])
crema_df = pd.concat([emotion_df, path_df], axis=1)
crema_df.to_csv("crema_df.csv", index=False)
crema_df.head()
# Out:
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Anger
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Disgust
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Fear
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Happy
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Neutral
# Checking folder: /kaggle/input/indian-emotion/Audio Mode Only/Sad
#   Emotions                                               Path
# 0    anger  /kaggle/input/indian-emotion/Audio Mode Only/A...
# 1    anger  /kaggle/input/indian-emotion/Audio Mode Only/A...
# 2    anger  /kaggle/input/indian-emotion/Audio Mode Only/A...
# 3    anger  /kaggle/input/indian-emotion/Audio Mode Only/A...
# 4    anger  /kaggle/input/indian-emotion/Audio Mode Only/A...

# %% [markdown]
# # Dataset

# %%
crema_df.to_csv('/kaggle/working/pumave.csv', index=False)
plt.title('Count of Emotions')
sns.countplot(x = crema_df.Emotions)
plt.ylabel('Count')
plt.xlabel('Emotions')
sns.despine(top = True, right = True, left = False, bottom = False)
plt.show()

# %%
def waveplot(data, sr, emotion, ax):
    ax.plot(data)
    ax.set_title(f'Waveplot for {emotion}')
    ax.set_xlabel('Time')
    ax.set_ylabel('Amplitude')

def spectrogram(data, sr, emotion, ax):
    S = librosa.stft(data)
    S_dB = librosa.amplitude_to_db(np.abs(S), ref=np.max)
    img = librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='log', ax=ax)
    ax.set_title(f'Spectrogram for {emotion}')
    return img

# %% [markdown]
# # Visualization

# %%
crema_df['Emotions'].unique()
# Out:
# array(['anger', 'disgust', 'fear', 'happy', 'neutral', 'sad'],
#       dtype=object)

# %%
emotions = ['happy', 'sad', 'anger', 'disgust', 'fear', 'neutral']
fig, axs = plt.subplots(len(emotions), 2, figsize=(15, 3 * len(emotions)))

for i, emotion in enumerate(emotions):
    emotion_paths = crema_df.Path[crema_df.Emotions == emotion]
    if not emotion_paths.empty:
        path = np.array(emotion_paths)[0]  # Take the first path
        data, sr = librosa.load(path)
        waveplot(data, sr, emotion, axs[i, 0])
        img = spectrogram(data, sr, emotion, axs[i, 1])
    else:
        print(f"No paths found for emotion '{emotion}'")

plt.tight_layout()
cbar = fig.colorbar(img, ax=axs[:, 1], format="%+2.0f dB")
cbar.ax.set_ylabel('Amplitude (dB)')
plt.show()

# %% [markdown]
# # MFCC Extraction

# %%
#labels = {'disgust':0,'happy':1,'sad':2,'neutral':3,'fear':4,'angry':5}
#pumave_df.replace({'Emotions':labels},inplace=True)

# %%
num_mfcc=13
n_fft=2048
hop_length=512
SAMPLE_RATE = 22050
data = {
        "labels": [],
        "mfcc": []
    }
for i in range(1232):
    data['labels'].append(crema_df.iloc[i,0])
    signal, sample_rate = librosa.load(crema_df.iloc[i,1], sr=SAMPLE_RATE)
    mfcc = librosa.feature.mfcc(signal, sample_rate, n_mfcc=13, n_fft=2048, hop_length=512)
    mfcc = mfcc.T
    data["mfcc"].append(np.asarray(mfcc))
    if i%500==0:
        print(i)
# Out:
# 0
# 500
# 1000

# %% [markdown]
# # Padding MFCC to make them of equal length

# %%
X = np.asarray(data['mfcc'])
y = np.asarray(data["labels"])

# %%
X = tf.keras.preprocessing.sequence.pad_sequences(X)
X.shape
# Out:
# (1232, 237, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2)

# %%
print(X_train.shape,y_train.shape,X_validation.shape,y_validation.shape,X_test.shape,y_test.shape)
# Out:
# (886, 237, 13) (886,) (222, 237, 13) (222,) (124, 237, 13) (124,)

# %% [markdown]
# # Model

# %%
def build_model(input_shape):
    model = tf.keras.Sequential([
        LSTM(128, input_shape=input_shape, return_sequences=True),
        LSTM(64),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(6, activation='softmax')
    ])
    return model

input_shape = (237, 13)
model = build_model(input_shape)

optimiser = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 237, 128)          72704
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 390
# =================================================================
# Total params: 126,662
# Trainable params: 126,662
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
print("Model input shape:", model.input_shape)
print("X_train shape:", X_train.shape)
# Out:
# Model input shape: (None, 237, 13)
# X_train shape: (886, 237, 13)

# %%
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=60)
# Out:
# Epoch 1/60
# 28/28 [==============================] - 1s 28ms/step - loss: 0.5022 - accuracy: 0.8104 - val_loss: 1.2006 - val_accuracy: 0.5631
# Epoch 2/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.4558 - accuracy: 0.8318 - val_loss: 1.2318 - val_accuracy: 0.5721
# Epoch 3/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.5027 - accuracy: 0.8047 - val_loss: 1.3980 - val_accuracy: 0.4414
# Epoch 4/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.5693 - accuracy: 0.7698 - val_loss: 1.3345 - val_accuracy: 0.4865
# Epoch 5/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.4663 - accuracy: 0.8375 - val_loss: 1.4506 - val_accuracy: 0.4685
# Epoch 6/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.4331 - accuracy: 0.8465 - val_loss: 1.5472 - val_accuracy: 0.5721
# Epoch 7/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.5816 - accuracy: 0.7822 - val_loss: 1.3393 - val_accuracy: 0.5225
# Epoch 8/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.4707 - accuracy: 0.8205 - val_loss: 1.4485 - val_accuracy: 0.5045
# Epoch 9/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3993 - accuracy: 0.8544 - val_loss: 1.5212 - val_accuracy: 0.5180
# Epoch 10/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3791 - accuracy: 0.8657 - val_loss: 1.4774 - val_accuracy: 0.5000
# Epoch 11/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3860 - accuracy: 0.8533 - val_loss: 1.6332 - val_accuracy: 0.4730
# Epoch 12/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3473 - accuracy: 0.8691 - val_loss: 1.5116 - val_accuracy: 0.4730
# Epoch 13/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3627 - accuracy: 0.8646 - val_loss: 1.6803 - val_accuracy: 0.5090
# Epoch 14/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3605 - accuracy: 0.8567 - val_loss: 1.4444 - val_accuracy: 0.5586
# Epoch 15/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3599 - accuracy: 0.8589 - val_loss: 1.4972 - val_accuracy: 0.5405
# Epoch 16/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2443 - accuracy: 0.9199 - val_loss: 1.7673 - val_accuracy: 0.5000
# Epoch 17/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1886 - accuracy: 0.9323 - val_loss: 1.9302 - val_accuracy: 0.5090
# Epoch 18/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2453 - accuracy: 0.9074 - val_loss: 2.2328 - val_accuracy: 0.4459
# Epoch 19/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3315 - accuracy: 0.8837 - val_loss: 1.6477 - val_accuracy: 0.5270
# Epoch 20/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2935 - accuracy: 0.8950 - val_loss: 1.6960 - val_accuracy: 0.5541
# Epoch 21/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2175 - accuracy: 0.9233 - val_loss: 1.7032 - val_accuracy: 0.5405
# Epoch 22/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2275 - accuracy: 0.9187 - val_loss: 1.9335 - val_accuracy: 0.5225
# Epoch 23/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1571 - accuracy: 0.9515 - val_loss: 1.9737 - val_accuracy: 0.5000
# Epoch 24/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1426 - accuracy: 0.9560 - val_loss: 2.0431 - val_accuracy: 0.5045
# Epoch 25/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1233 - accuracy: 0.9537 - val_loss: 1.9901 - val_accuracy: 0.4955
# Epoch 26/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1571 - accuracy: 0.9447 - val_loss: 2.1810 - val_accuracy: 0.4730
# Epoch 27/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2283 - accuracy: 0.9131 - val_loss: 1.8419 - val_accuracy: 0.5360
# Epoch 28/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.4125 - accuracy: 0.8634 - val_loss: 1.6292 - val_accuracy: 0.5360
# Epoch 29/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2532 - accuracy: 0.9097 - val_loss: 1.8784 - val_accuracy: 0.4685
# Epoch 30/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2550 - accuracy: 0.9165 - val_loss: 1.9829 - val_accuracy: 0.5090
# Epoch 31/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2648 - accuracy: 0.9086 - val_loss: 1.8382 - val_accuracy: 0.5135
# Epoch 32/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.3566 - accuracy: 0.8646 - val_loss: 1.7902 - val_accuracy: 0.5315
# Epoch 33/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1990 - accuracy: 0.9368 - val_loss: 1.7608 - val_accuracy: 0.4910
# Epoch 34/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1289 - accuracy: 0.9560 - val_loss: 1.6914 - val_accuracy: 0.5495
# Epoch 35/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1133 - accuracy: 0.9594 - val_loss: 2.0859 - val_accuracy: 0.5225
# Epoch 36/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1102 - accuracy: 0.9628 - val_loss: 2.1068 - val_accuracy: 0.5676
# Epoch 37/60
# 28/28 [==============================] - 1s 26ms/step - loss: 0.1482 - accuracy: 0.9492 - val_loss: 2.0640 - val_accuracy: 0.5405
# Epoch 38/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1502 - accuracy: 0.9458 - val_loss: 2.0625 - val_accuracy: 0.5045
# Epoch 39/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1594 - accuracy: 0.9447 - val_loss: 2.1876 - val_accuracy: 0.5135
# Epoch 40/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2850 - accuracy: 0.9063 - val_loss: 2.0011 - val_accuracy: 0.5000
# Epoch 41/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1964 - accuracy: 0.9323 - val_loss: 1.8588 - val_accuracy: 0.5405
# Epoch 42/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2009 - accuracy: 0.9323 - val_loss: 1.8764 - val_accuracy: 0.5360
# Epoch 43/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2121 - accuracy: 0.9199 - val_loss: 1.6630 - val_accuracy: 0.5000
# Epoch 44/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1468 - accuracy: 0.9470 - val_loss: 1.8572 - val_accuracy: 0.5225
# Epoch 45/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1432 - accuracy: 0.9503 - val_loss: 1.7503 - val_accuracy: 0.5541
# Epoch 46/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0798 - accuracy: 0.9740 - val_loss: 1.9322 - val_accuracy: 0.5856
# Epoch 47/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0844 - accuracy: 0.9718 - val_loss: 1.9117 - val_accuracy: 0.5811
# Epoch 48/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0669 - accuracy: 0.9786 - val_loss: 2.0685 - val_accuracy: 0.5721
# Epoch 49/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0618 - accuracy: 0.9808 - val_loss: 2.1423 - val_accuracy: 0.6036
# Epoch 50/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0998 - accuracy: 0.9729 - val_loss: 2.2065 - val_accuracy: 0.5586
# Epoch 51/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1846 - accuracy: 0.9391 - val_loss: 2.3160 - val_accuracy: 0.4685
# Epoch 52/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.2415 - accuracy: 0.9244 - val_loss: 1.9090 - val_accuracy: 0.5450
# Epoch 53/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1365 - accuracy: 0.9537 - val_loss: 1.8262 - val_accuracy: 0.5586
# Epoch 54/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1100 - accuracy: 0.9661 - val_loss: 2.0526 - val_accuracy: 0.5450
# Epoch 55/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0725 - accuracy: 0.9797 - val_loss: 2.2213 - val_accuracy: 0.5405
# Epoch 56/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0843 - accuracy: 0.9707 - val_loss: 2.1628 - val_accuracy: 0.5360
# Epoch 57/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.1070 - accuracy: 0.9616 - val_loss: 2.0799 - val_accuracy: 0.5405
# Epoch 58/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0622 - accuracy: 0.9819 - val_loss: 2.1417 - val_accuracy: 0.5586
# Epoch 59/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0448 - accuracy: 0.9865 - val_loss: 2.2215 - val_accuracy: 0.5631
# Epoch 60/60
# 28/28 [==============================] - 1s 25ms/step - loss: 0.0641 - accuracy: 0.9808 - val_loss: 2.2832 - val_accuracy: 0.5270

# %% [markdown]
# # Evaluation

# %%
print("X_test dtype:", X_test.shape)
print("y_test dtype:", y_test.shape)
# Out:
# X_test dtype: (124, 237, 13)
# y_test dtype: (124,)

# %%
X_test = X_test.astype(np.float32)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_test = le.fit_transform(y_test).astype(np.int32)
print("X_test dtype:", X_test.dtype)
print("y_test dtype:", y_test.dtype)
print("Unique values in y_test:", np.unique(y_test))
# Out:
# X_test dtype: float32
# y_test dtype: int32
# Unique values in y_test: [0 1 2 3 4 5]

# %%
print("Testing Accuracy: " , model.evaluate(X_test,y_test)[1]*100 , "%")

epochs = [i for i in range(60)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(20,6)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 4/4 [==============================] - 0s 11ms/step - loss: 2.7443 - accuracy: 0.5242
# Testing Accuracy:  52.419352531433105 %

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print("Test Accuracy: ",test_acc)
# Out:
# Test Accuracy:  0.524193525314331

# %%
import numpy as np
import pandas as pd
import os
import librosa
import librosa.display
import IPython
from IPython.display import Audio
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
DATA_PATH = '/kaggle/input/cremad/AudioWAV'
SAMPLE_RATE = 16000
data = pd.read_csv('/kaggle/input/crema-dataframe/crema_df.csv')
print(data)
# Out:
#      Emotions                                               Path
# 0     disgust  /kaggle/input/cremad/AudioWAV/1028_TSI_DIS_XX.wav
# 1       happy  /kaggle/input/cremad/AudioWAV/1075_IEO_HAP_LO.wav
# 2       happy  /kaggle/input/cremad/AudioWAV/1084_ITS_HAP_XX.wav
# 3     disgust  /kaggle/input/cremad/AudioWAV/1067_IWW_DIS_XX.wav
# 4     disgust  /kaggle/input/cremad/AudioWAV/1066_TIE_DIS_XX.wav
# ...       ...                                                ...
# 7437    angry  /kaggle/input/cremad/AudioWAV/1060_IEO_ANG_MD.wav
# 7438    angry  /kaggle/input/cremad/AudioWAV/1088_IWL_ANG_XX.wav
# 7439    angry  /kaggle/input/cremad/AudioWAV/1050_IOM_ANG_XX.wav
# 7440      sad  /kaggle/input/cremad/AudioWAV/1044_IWL_SAD_XX.wav
# 7441      sad  /kaggle/input/cremad/AudioWAV/1009_ITH_SAD_XX.wav
#
# [7442 rows x 2 columns]

# %%
unique_emotions = data['Emotions'].unique()
print(unique_emotions)
# Out:
# ['disgust' 'happy' 'sad' 'neutral' 'fear' 'angry']

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.bar(x=range(len(unique_emotions)), height=data['Emotions'].value_counts().loc[unique_emotions])
ax.set_xticks(ticks=range(len(unique_emotions)))
ax.set_xlabel('Emotions')
ax.set_ylabel('Number of examples')
plt.show()

# %%
signals = []
for i, file_path in enumerate(data.Path):
    audio, _ = librosa.load(file_path, duration=3, offset=0.5, sr=SAMPLE_RATE)
    signal = np.zeros((int(SAMPLE_RATE * 3,)))
    signal[:len(audio)] = audio
    signals.append(signal)
    print("\rProcessed {}/{} files".format(i + 1, len(data)), end='')

signals = np.stack(signals, axis=0)
print("\nShape of signals array:", signals.shape)
# Out:
# Processed 7442/7442 files
# Shape of signals array: (7442, 48000)

# %%
EMOTIONS = {1: 'neutral', 2: 'happy', 3: 'sad', 4: 'angry', 5: 'fear', 0: 'disgust'}
emotion_to_int = {v: k for k, v in EMOTIONS.items()}
mel_spectrograms = []
X = signals
train_ind, test_ind, val_ind = [], [], []
X_train, X_val, X_test = [], [], []
Y_train, Y_val, Y_test = [], [], []

for emotion in EMOTIONS.values():
    emotion_ind = list(data.loc[data.Emotions == emotion, 'Emotions'].index)
    emotion_ind = np.random.permutation(emotion_ind).astype(int)  # Ensure indices are integers
    m = len(emotion_ind)
    ind_train = emotion_ind[:int(0.8 * m)]
    ind_val = emotion_ind[int(0.8 * m):int(0.9 * m)]
    ind_test = emotion_ind[int(0.9 * m):]
    
    # Ensure indices are within the bounds of the signals array
    ind_train = [i for i in ind_train if i < signals.shape[0]]
    ind_val = [i for i in ind_val if i < signals.shape[0]]
    ind_test = [i for i in ind_test if i < signals.shape[0]]
    
    if ind_train:
        X_train.append(signals[ind_train, :])
        Y_train.append(np.array([emotion_to_int[emotion]] * len(ind_train), dtype=np.int32))
    if ind_val:
        X_val.append(signals[ind_val, :])
        Y_val.append(np.array([emotion_to_int[emotion]] * len(ind_val), dtype=np.int32))
    if ind_test:
        X_test.append(signals[ind_test, :])
        Y_test.append(np.array([emotion_to_int[emotion]] * len(ind_test), dtype=np.int32))
    
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)

X_train = np.concatenate(X_train, 0) if X_train else np.array([])
X_val = np.concatenate(X_val, 0) if X_val else np.array([])
X_test = np.concatenate(X_test, 0) if X_test else np.array([])
Y_train = np.concatenate(Y_train, 0) if Y_train else np.array([])
Y_val = np.concatenate(Y_val, 0) if Y_val else np.array([])
Y_test = np.concatenate(Y_test, 0) if Y_test else np.array([])
train_ind = np.concatenate(train_ind, 0) if train_ind else np.array([])
val_ind = np.concatenate(val_ind, 0) if val_ind else np.array([])
test_ind = np.concatenate(test_ind, 0) if test_ind else np.array([])

print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
print(f'X_val: {X_val.shape}, Y_val: {Y_val.shape}')
print(f'X_test: {X_test.shape}, Y_test: {Y_test.shape}')

# Check if all are unique
unique, count = np.unique(np.concatenate([train_ind, test_ind, val_ind], 0), return_counts=True)
print("Number of unique indexes is {}, out of {}".format(sum(count == 1), signals.shape[0]))
del signals
# Out:
# X_train: (5949, 48000), Y_train: (5949,)
# X_val: (744, 48000), Y_val: (744,)
# X_test: (749, 48000), Y_test: (749,)
# Number of unique indexes is 7442, out of 7442

# %%
def addAWGN(signal, num_bits=16, augmented_num=2, snr_low=15, snr_high=30): 
    signal_len = len(signal)
    # Generate White Gaussian noise
    noise = np.random.normal(size=(augmented_num, signal_len))
    # Normalize signal and noise
    norm_constant = 2.0**(num_bits-1)
    signal_norm = signal / norm_constant
    noise_norm = noise / norm_constant
    # Compute signal and noise power
    s_power = np.sum(signal_norm ** 2) / signal_len
    n_power = np.sum(noise_norm ** 2, axis=1) / signal_len
    # Random SNR: Uniform [15, 30] in dB
    target_snr = np.random.randint(snr_low, snr_high)
    # Compute K (covariance matrix) for each noise 
    K = np.sqrt((s_power / n_power) * 10 ** (- target_snr / 10))
    K = np.ones((signal_len, augmented_num)) * K  
    # Generate noisy signal
    return signal + K.T * noise

# %%
aug_signals = []
aug_labels = []
new_data_rows = []

for i in range(X_train.shape[0]):
    signal = X_train[i, :]
    augmented_signal = addAWGN(signal)
    
    if augmented_signal.shape != signal.shape:
        augmented_signal = augmented_signal[0, :]  

    aug_labels.append(Y_train[i]) 
    aug_signals.append(augmented_signal)
    
    new_row = data.iloc[i].copy()
    new_data_rows.append(new_row)
    
    print("\r Processed {}/{} files".format(i + 1, X_train.shape[0]), end='')

aug_signals = np.stack(aug_signals, axis=0)

#print(f"aug_signals shape: {aug_signals.shape}")

X_train = np.concatenate([X_train, aug_signals], axis=0)
aug_labels = np.array(aug_labels)
Y_train = np.concatenate([Y_train, aug_labels])

new_data_df = pd.DataFrame(new_data_rows)
data = pd.concat([data, new_data_df], ignore_index=True)

print('')
print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
# Out:
#  Processed 5949/5949 files
# X_train: (11898, 48000), Y_train: (11898,)

# %%
print(f"signal shape: {signal.shape}")
print(f"augmented_signal shape: {augmented_signal.shape}")
print(f"aug_signals shape: {aug_signals.shape}")
print(f'X_train: {X_train.shape}, Y_train: {Y_train.shape}')
# Out:
# signal shape: (48000,)
# augmented_signal shape: (48000,)
# aug_signals shape: (5949, 48000)
# X_train: (11898, 48000), Y_train: (11898,)

# %%
def getMELspectrogram(audio, sample_rate):
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# test function
audio, sample_rate = librosa.load(data.loc[0,'Path'], duration=3, offset=0.5,sr=SAMPLE_RATE)
signal = np.zeros((int(SAMPLE_RATE*3,)))
signal[:len(audio)] = audio
mel_spectrogram = getMELspectrogram(signal, SAMPLE_RATE)
librosa.display.specshow(mel_spectrogram, y_axis='mel', x_axis='time')
print('MEL spectrogram shape: ',mel_spectrogram.shape)
# Out:
# MEL spectrogram shape:  (128, 188)

# %%
mel_train = []
print("Calculatin mel spectrograms for train set")
for i in range(X_train.shape[0]):
    mel_spectrogram = getMELspectrogram(X_train[i,:], sample_rate=SAMPLE_RATE)
    mel_train.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_train.shape[0]),end='')
print('')
mel_train = np.stack(mel_train,axis=0)
del X_train
X_train = mel_train

mel_val = []
print("Calculatin mel spectrograms for val set")
for i in range(X_val.shape[0]):
    mel_spectrogram = getMELspectrogram(X_val[i,:], sample_rate=SAMPLE_RATE)
    mel_val.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_val.shape[0]),end='')
print('')
mel_val = np.stack(mel_val,axis=0)
del X_val
X_val = mel_val

mel_test = []
print("Calculatin mel spectrograms for test set")
for i in range(X_test.shape[0]):
    mel_spectrogram = getMELspectrogram(X_test[i,:], sample_rate=SAMPLE_RATE)
    mel_test.append(mel_spectrogram)
    print("\r Processed {}/{} files".format(i,X_test.shape[0]),end='')
print('')
mel_test = np.stack(mel_test,axis=0)
del X_test
X_test = mel_test

print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# Calculatin mel spectrograms for train set
#  Processed 11897/11898 files
# Calculatin mel spectrograms for val set
#  Processed 743/744 files
# Calculatin mel spectrograms for test set
#  Processed 748/749 files
# X_train:(11898, 128, 188), Y_train:(11898,)
# X_val:(744, 128, 188), Y_val:(744,)
# X_test:(749, 128, 188), Y_test:(749,)

# %%
import torch
import torch.nn as nn

class ParallelModel(nn.Module):
    def __init__(self,num_emotions):
        super().__init__()
        # conv block
        self.conv2Dblock = nn.Sequential(
            # 1. conv block
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # 2. conv block
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 3. conv block
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # 4. conv block
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        # Transformer block
        self.transf_maxpool = nn.MaxPool2d(kernel_size=[2,4], stride=[2,4])
        transf_layer = nn.TransformerEncoderLayer(d_model=64, nhead=4, dim_feedforward=512, dropout=0.4, activation='relu')
        self.transf_encoder = nn.TransformerEncoder(transf_layer, num_layers=4)
        # Linear softmax layer
        self.out_linear = nn.Linear(128,num_emotions)
        self.dropout_linear = nn.Dropout(p=0)
        self.out_softmax = nn.Softmax(dim=1)
        
        
        
    def forward(self,x):
        # conv embedding
        conv_embedding = self.conv2Dblock(x) #(b,channel,freq,time)
        conv_embedding = torch.flatten(conv_embedding, start_dim=1)
        #print("Conv embedding shape:", conv_embedding.shape)# do not flatten batch dimension
        
        # transformer embedding
        x_reduced = self.transf_maxpool(x)
        x_reduced = torch.squeeze(x_reduced,1)
        x_reduced = x_reduced.permute(2,0,1) # requires shape = (time,batch,embedding)
        transf_out = self.transf_encoder(x_reduced)
        transf_embedding = torch.mean(transf_out, dim=0)
        #print("Attention shape:", transf_embedding.shape)
        
        
        # concatenate
        complete_embedding = torch.cat([conv_embedding, transf_embedding], dim=1) 
        #print("Complete embedding shape:", complete_embedding.shape)
        # final Linear
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        output_softmax = self.out_softmax(output_logits)
        return output_logits, output_softmax

# %%
def loss_fnc(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
def make_train_step(model, loss_fnc, optimizer):
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        # compute loss
        loss = loss_fnc(output_logits, Y)
        # compute gradients
        loss.backward()
        # update parameters and zero gradients
        optimizer.step()
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model,loss_fnc):
    def validate(X,Y):
        with torch.no_grad():
            model.eval()
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            loss = loss_fnc(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
#X_train = np.expand_dims(X_train, axis=1)
#X_val = np.expand_dims(X_val, axis=1)
#X_test = np.expand_dims(X_test, axis=1)
print("Shape after expand_dims:")
print(f"X_train: {X_train.shape}")
print(f"X_val: {X_val.shape}")
print(f"X_test: {X_test.shape}")
# Out:
# Shape after expand_dims:
# X_train: (11898, 1, 128, 188)
# X_val: (744, 1, 128, 188)
# X_test: (749, 1, 128, 188)

# %%
EPOCHS=100
DATASET_SIZE = X_train.shape[0]
BATCH_SIZE = 32
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
model = ParallelModel(num_emotions=len(EMOTIONS)).to(device)
print('Number of trainable params: ',sum(p.numel() for p in model.parameters()) )
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)

train_step = make_train_step(model, loss_fnc, optimizer=OPTIMIZER)
validate = make_validate_fnc(model,loss_fnc)
losses=[]
val_losses = []
for epoch in range(EPOCHS):
    # schuffle data
    ind = np.random.permutation(DATASET_SIZE)
    X_train = X_train[ind,:,:,:]
    Y_train = Y_train[ind]
    epoch_acc = 0
    epoch_loss = 0
    iters = int(DATASET_SIZE / BATCH_SIZE)
    for i in range(iters):
        batch_start = i * BATCH_SIZE
        batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
        actual_batch_size = batch_end-batch_start
        X = X_train[batch_start:batch_end,:,:,:]
        Y = Y_train[batch_start:batch_end]
        X_tensor = torch.tensor(X,device=device).float()
        Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
        loss, acc = train_step(X_tensor,Y_tensor)
        epoch_acc += acc*actual_batch_size/DATASET_SIZE
        epoch_loss += loss*actual_batch_size/DATASET_SIZE
        print(f"\r Epoch {epoch}: iteration {i}/{iters}",end='')
    X_val_tensor = torch.tensor(X_val,device=device).float()
    Y_val_tensor = torch.tensor(Y_val,dtype=torch.long,device=device)
    val_loss, val_acc, _ = validate(X_val_tensor,Y_val_tensor)
    losses.append(epoch_loss)
    val_losses.append(val_loss)
    print('')
    print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")
# Out:
# Selected device is cuda
# Number of trainable params:  393382
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
#  Epoch 0: iteration 370/371
# Epoch 0 --> loss:1.6053, acc:32.68%, val_loss:1.7630, val_acc:33.33%
#  Epoch 1: iteration 370/371
# Epoch 1 --> loss:1.4674, acc:39.07%, val_loss:1.4286, val_acc:40.46%
#  Epoch 2: iteration 370/371
# Epoch 2 --> loss:1.4324, acc:41.02%, val_loss:1.5733, val_acc:34.95%
#  Epoch 3: iteration 370/371
# Epoch 3 --> loss:1.3972, acc:42.75%, val_loss:1.4606, val_acc:43.15%
#  Epoch 4: iteration 370/371
# Epoch 4 --> loss:1.3683, acc:44.69%, val_loss:1.3706, val_acc:44.76%
#  Epoch 5: iteration 370/371
# Epoch 5 --> loss:1.3422, acc:45.71%, val_loss:1.3143, val_acc:48.39%
#  Epoch 6: iteration 370/371
# Epoch 6 --> loss:1.3216, acc:46.87%, val_loss:1.3576, val_acc:45.16%
#  Epoch 7: iteration 370/371
# Epoch 7 --> loss:1.3063, acc:47.50%, val_loss:1.4198, val_acc:44.62%
#  Epoch 8: iteration 370/371
# Epoch 8 --> loss:1.2837, acc:48.44%, val_loss:1.3124, val_acc:47.04%
#  Epoch 9: iteration 370/371
# Epoch 9 --> loss:1.2684, acc:49.65%, val_loss:1.4729, val_acc:43.01%
#  Epoch 10: iteration 370/371
# Epoch 10 --> loss:1.2685, acc:49.66%, val_loss:1.2899, val_acc:48.79%
#  Epoch 11: iteration 370/371
# Epoch 11 --> loss:1.2460, acc:49.72%, val_loss:1.3827, val_acc:44.22%
#  Epoch 12: iteration 370/371
# Epoch 12 --> loss:1.2329, acc:51.08%, val_loss:1.3471, val_acc:49.73%
#  Epoch 13: iteration 370/371
# Epoch 13 --> loss:1.2054, acc:52.06%, val_loss:1.2757, val_acc:50.27%
#  Epoch 14: iteration 370/371
# Epoch 14 --> loss:1.1971, acc:52.47%, val_loss:1.4459, val_acc:42.34%
#  Epoch 15: iteration 370/371
# Epoch 15 --> loss:1.1879, acc:52.40%, val_loss:1.3320, val_acc:48.12%
#  Epoch 16: iteration 370/371
# Epoch 16 --> loss:1.1752, acc:53.85%, val_loss:1.2937, val_acc:48.12%
#  Epoch 17: iteration 370/371
# Epoch 17 --> loss:1.1555, acc:54.39%, val_loss:1.2038, val_acc:52.69%
#  Epoch 18: iteration 370/371
# Epoch 18 --> loss:1.1367, acc:55.09%, val_loss:1.2233, val_acc:52.69%
#  Epoch 19: iteration 370/371
# Epoch 19 --> loss:1.1301, acc:55.58%, val_loss:1.2316, val_acc:55.51%
#  Epoch 20: iteration 370/371
# Epoch 20 --> loss:1.1154, acc:56.95%, val_loss:1.4364, val_acc:44.09%
#  Epoch 21: iteration 370/371
# Epoch 21 --> loss:1.1066, acc:57.03%, val_loss:1.2245, val_acc:51.88%
#  Epoch 22: iteration 370/371
# Epoch 22 --> loss:1.0905, acc:57.51%, val_loss:1.2367, val_acc:52.55%
#  Epoch 23: iteration 370/371
# Epoch 23 --> loss:1.0845, acc:57.67%, val_loss:1.1837, val_acc:53.76%
#  Epoch 24: iteration 370/371
# Epoch 24 --> loss:1.0607, acc:58.60%, val_loss:1.2321, val_acc:53.36%
#  Epoch 25: iteration 370/371
# Epoch 25 --> loss:1.0633, acc:58.44%, val_loss:1.1321, val_acc:56.18%
#  Epoch 26: iteration 370/371
# Epoch 26 --> loss:1.0534, acc:58.88%, val_loss:1.0692, val_acc:59.27%
#  Epoch 27: iteration 370/371
# Epoch 27 --> loss:1.0357, acc:59.09%, val_loss:1.2031, val_acc:52.42%
#  Epoch 28: iteration 370/371
# Epoch 28 --> loss:1.0266, acc:59.67%, val_loss:1.1934, val_acc:53.36%
#  Epoch 29: iteration 370/371
# Epoch 29 --> loss:1.0148, acc:60.53%, val_loss:1.1916, val_acc:54.97%
#  Epoch 30: iteration 370/371
# Epoch 30 --> loss:1.0041, acc:61.46%, val_loss:1.2430, val_acc:52.28%
#  Epoch 31: iteration 370/371
# Epoch 31 --> loss:1.0016, acc:60.93%, val_loss:1.4232, val_acc:47.31%
#  Epoch 32: iteration 370/371
# Epoch 32 --> loss:1.0002, acc:60.86%, val_loss:1.1869, val_acc:54.70%
#  Epoch 33: iteration 370/371
# Epoch 33 --> loss:0.9748, acc:62.22%, val_loss:1.5733, val_acc:44.49%
#  Epoch 34: iteration 370/371
# Epoch 34 --> loss:0.9784, acc:62.07%, val_loss:1.3378, val_acc:49.46%
#  Epoch 35: iteration 370/371
# Epoch 35 --> loss:0.9593, acc:63.21%, val_loss:1.2396, val_acc:51.61%
#  Epoch 36: iteration 370/371
# Epoch 36 --> loss:0.9585, acc:62.89%, val_loss:1.2219, val_acc:50.94%
#  Epoch 37: iteration 370/371
# Epoch 37 --> loss:0.9524, acc:63.41%, val_loss:1.2310, val_acc:52.96%
#  Epoch 38: iteration 370/371
# Epoch 38 --> loss:0.9515, acc:63.01%, val_loss:1.4370, val_acc:44.35%
#  Epoch 39: iteration 370/371
# Epoch 39 --> loss:0.9313, acc:63.94%, val_loss:1.2288, val_acc:53.63%
#  Epoch 40: iteration 370/371
# Epoch 40 --> loss:0.9397, acc:63.84%, val_loss:1.2704, val_acc:50.40%
#  Epoch 41: iteration 370/371
# Epoch 41 --> loss:0.9252, acc:64.23%, val_loss:1.1319, val_acc:56.85%
#  Epoch 42: iteration 370/371
# Epoch 42 --> loss:0.9117, acc:64.25%, val_loss:1.0819, val_acc:59.27%
#  Epoch 43: iteration 370/371
# Epoch 43 --> loss:0.9079, acc:65.20%, val_loss:1.2898, val_acc:51.34%
#  Epoch 44: iteration 370/371
# Epoch 44 --> loss:0.9069, acc:65.17%, val_loss:1.1872, val_acc:55.11%
#  Epoch 45: iteration 370/371
# Epoch 45 --> loss:0.8965, acc:65.27%, val_loss:1.0325, val_acc:61.16%
#  Epoch 46: iteration 370/371
# Epoch 46 --> loss:0.8837, acc:66.22%, val_loss:1.2840, val_acc:51.48%
#  Epoch 47: iteration 370/371
# Epoch 47 --> loss:0.8887, acc:65.89%, val_loss:1.3475, val_acc:49.60%
#  Epoch 48: iteration 370/371
# Epoch 48 --> loss:0.8819, acc:66.10%, val_loss:1.1169, val_acc:58.47%
#  Epoch 49: iteration 370/371
# Epoch 49 --> loss:0.8765, acc:66.24%, val_loss:1.2124, val_acc:54.84%
#  Epoch 50: iteration 370/371
# Epoch 50 --> loss:0.8708, acc:65.94%, val_loss:1.3289, val_acc:48.12%
#  Epoch 51: iteration 370/371
# Epoch 51 --> loss:0.8696, acc:66.27%, val_loss:1.1854, val_acc:53.23%
#  Epoch 52: iteration 370/371
# Epoch 52 --> loss:0.8673, acc:66.84%, val_loss:1.2163, val_acc:55.11%
#  Epoch 53: iteration 370/371
# Epoch 53 --> loss:0.8585, acc:67.13%, val_loss:1.0757, val_acc:57.66%
#  Epoch 54: iteration 370/371
# Epoch 54 --> loss:0.8657, acc:66.89%, val_loss:1.1398, val_acc:57.53%
#  Epoch 55: iteration 370/371
# Epoch 55 --> loss:0.8526, acc:67.08%, val_loss:1.0155, val_acc:60.75%
#  Epoch 56: iteration 370/371
# Epoch 56 --> loss:0.8456, acc:67.43%, val_loss:1.0534, val_acc:58.20%
#  Epoch 57: iteration 370/371
# Epoch 57 --> loss:0.8416, acc:67.01%, val_loss:1.1058, val_acc:57.12%
#  Epoch 58: iteration 370/371
# Epoch 58 --> loss:0.8486, acc:67.62%, val_loss:1.0769, val_acc:57.53%
#  Epoch 59: iteration 370/371
# Epoch 59 --> loss:0.8299, acc:67.83%, val_loss:1.1612, val_acc:56.72%
#  Epoch 60: iteration 370/371
# Epoch 60 --> loss:0.8322, acc:67.87%, val_loss:1.0238, val_acc:61.56%
#  Epoch 61: iteration 370/371
# Epoch 61 --> loss:0.8252, acc:68.33%, val_loss:0.9843, val_acc:63.04%
#  Epoch 62: iteration 370/371
# Epoch 62 --> loss:0.8270, acc:68.39%, val_loss:1.1618, val_acc:55.51%
#  Epoch 63: iteration 370/371
# Epoch 63 --> loss:0.8189, acc:68.20%, val_loss:1.1045, val_acc:59.14%
#  Epoch 64: iteration 370/371
# Epoch 64 --> loss:0.8177, acc:68.46%, val_loss:1.2443, val_acc:51.75%
#  Epoch 65: iteration 370/371
# Epoch 65 --> loss:0.8135, acc:68.68%, val_loss:1.1825, val_acc:54.44%
#  Epoch 66: iteration 370/371
# Epoch 66 --> loss:0.8098, acc:69.03%, val_loss:1.1149, val_acc:58.20%
#  Epoch 67: iteration 370/371
# Epoch 67 --> loss:0.8047, acc:69.09%, val_loss:1.0209, val_acc:61.56%
#  Epoch 68: iteration 370/371
# Epoch 68 --> loss:0.8021, acc:69.12%, val_loss:1.0806, val_acc:61.02%
#  Epoch 69: iteration 370/371
# Epoch 69 --> loss:0.8019, acc:69.05%, val_loss:1.0553, val_acc:61.02%
#  Epoch 70: iteration 370/371
# Epoch 70 --> loss:0.7987, acc:69.37%, val_loss:1.1717, val_acc:58.33%
#  Epoch 71: iteration 370/371
# Epoch 71 --> loss:0.7964, acc:69.99%, val_loss:1.1010, val_acc:59.81%
#  Epoch 72: iteration 370/371
# Epoch 72 --> loss:0.8004, acc:68.58%, val_loss:1.0452, val_acc:59.14%
#  Epoch 73: iteration 370/371
# Epoch 73 --> loss:0.7898, acc:69.27%, val_loss:1.0750, val_acc:60.75%
#  Epoch 74: iteration 370/371
# Epoch 74 --> loss:0.7796, acc:69.78%, val_loss:1.1135, val_acc:58.87%
#  Epoch 75: iteration 370/371
# Epoch 75 --> loss:0.7807, acc:69.94%, val_loss:1.1946, val_acc:53.49%
#  Epoch 76: iteration 370/371
# Epoch 76 --> loss:0.7835, acc:70.67%, val_loss:1.2415, val_acc:54.97%
#  Epoch 77: iteration 370/371
# Epoch 77 --> loss:0.7865, acc:69.87%, val_loss:1.1799, val_acc:56.59%
#  Epoch 78: iteration 370/371
# Epoch 78 --> loss:0.7672, acc:71.20%, val_loss:1.0800, val_acc:60.62%
#  Epoch 79: iteration 370/371
# Epoch 79 --> loss:0.7785, acc:70.47%, val_loss:1.1178, val_acc:59.95%
#  Epoch 80: iteration 370/371
# Epoch 80 --> loss:0.7779, acc:69.48%, val_loss:1.3340, val_acc:49.46%
#  Epoch 81: iteration 370/371
# Epoch 81 --> loss:0.7636, acc:70.56%, val_loss:1.2104, val_acc:56.59%
#  Epoch 82: iteration 370/371
# Epoch 82 --> loss:0.7552, acc:71.56%, val_loss:1.1339, val_acc:57.53%
#  Epoch 83: iteration 370/371
# Epoch 83 --> loss:0.7497, acc:71.04%, val_loss:1.2464, val_acc:54.97%
#  Epoch 84: iteration 370/371
# Epoch 84 --> loss:0.7487, acc:71.59%, val_loss:1.2088, val_acc:53.09%
#  Epoch 85: iteration 370/371
# Epoch 85 --> loss:0.7506, acc:71.58%, val_loss:1.0684, val_acc:60.62%
#  Epoch 86: iteration 370/371
# Epoch 86 --> loss:0.7415, acc:71.82%, val_loss:1.1455, val_acc:57.53%
#  Epoch 87: iteration 370/371
# Epoch 87 --> loss:0.7494, acc:71.80%, val_loss:1.1186, val_acc:60.08%
#  Epoch 88: iteration 370/371
# Epoch 88 --> loss:0.7374, acc:71.51%, val_loss:1.1720, val_acc:59.14%
#  Epoch 89: iteration 370/371
# Epoch 89 --> loss:0.7426, acc:71.69%, val_loss:1.1732, val_acc:58.06%
#  Epoch 90: iteration 370/371
# Epoch 90 --> loss:0.7347, acc:72.10%, val_loss:1.1148, val_acc:60.22%
#  Epoch 91: iteration 370/371
# Epoch 91 --> loss:0.7335, acc:71.89%, val_loss:1.1950, val_acc:55.91%
#  Epoch 92: iteration 370/371
# Epoch 92 --> loss:0.7337, acc:71.96%, val_loss:1.2035, val_acc:58.06%
#  Epoch 93: iteration 370/371
# Epoch 93 --> loss:0.7363, acc:72.18%, val_loss:1.1365, val_acc:56.32%
#  Epoch 94: iteration 370/371
# Epoch 94 --> loss:0.7220, acc:72.73%, val_loss:1.0941, val_acc:59.81%
#  Epoch 95: iteration 370/371
# Epoch 95 --> loss:0.7224, acc:72.73%, val_loss:1.3117, val_acc:54.70%
#  Epoch 96: iteration 370/371
# Epoch 96 --> loss:0.7344, acc:72.21%, val_loss:1.1793, val_acc:55.65%
#  Epoch 97: iteration 370/371
# Epoch 97 --> loss:0.7140, acc:72.47%, val_loss:1.2014, val_acc:57.53%
#  Epoch 98: iteration 370/371
# Epoch 98 --> loss:0.7112, acc:73.05%, val_loss:1.2242, val_acc:57.80%
#  Epoch 99: iteration 370/371
# Epoch 99 --> loss:0.7168, acc:72.59%, val_loss:1.0943, val_acc:59.14%

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_attention_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_attention_model.pt')))
# Out:
# Model is saved to /kaggle/working/models/cnn_attention_model.pt

# %%
import sklearn.metrics as metrics

X_test_tensor = torch.tensor(X_test, device=device).float()
Y_test_tensor = torch.tensor(Y_test, dtype=torch.long, device=device)
test_loss, test_acc, predictions = validate(X_test_tensor, Y_test_tensor)

if isinstance(predictions, torch.Tensor):
    predictions = predictions.cpu().numpy()

true_labels = Y_test_tensor.cpu().numpy()

recall = metrics.recall_score(true_labels, predictions, average='weighted')
f1 = metrics.f1_score(true_labels, predictions, average='weighted')

print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
print(f'Test recall is {recall:.2f}')
print(f'Test F1 score is {f1:.2f}')
# Out:
# Test loss is 1.135
# Test accuracy is 58.21%
# Test recall is 0.58
# Test F1 score is 0.58

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

cm = confusion_matrix(Y_test, predictions)
names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
df_cm = pd.DataFrame(cm, index=names, columns=names)

plt.figure(figsize=(10,7))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16})
plt.show()

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.legend(['train loss','val loss'])

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /opt/conda/lib/python3.10/site-packages (1.8.0)

# %%
from torchinfo import summary
input_size = (32, 1, 128, 188)  
summary(model, input_size=input_size, device='cuda')
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ParallelModel                                 [32, 6]                   --
# ├─Sequential: 1-1                             [32, 64, 1, 1]            --
# │    └─Conv2d: 2-1                            [32, 16, 128, 188]        160
# │    └─BatchNorm2d: 2-2                       [32, 16, 128, 188]        32
# │    └─ReLU: 2-3                              [32, 16, 128, 188]        --
# │    └─MaxPool2d: 2-4                         [32, 16, 64, 94]          --
# │    └─Dropout: 2-5                           [32, 16, 64, 94]          --
# │    └─Conv2d: 2-6                            [32, 32, 64, 94]          4,640
# │    └─BatchNorm2d: 2-7                       [32, 32, 64, 94]          64
# │    └─ReLU: 2-8                              [32, 32, 64, 94]          --
# │    └─MaxPool2d: 2-9                         [32, 32, 16, 23]          --
# │    └─Dropout: 2-10                          [32, 32, 16, 23]          --
# │    └─Conv2d: 2-11                           [32, 64, 16, 23]          18,496
# │    └─BatchNorm2d: 2-12                      [32, 64, 16, 23]          128
# │    └─ReLU: 2-13                             [32, 64, 16, 23]          --
# │    └─MaxPool2d: 2-14                        [32, 64, 4, 5]            --
# │    └─Dropout: 2-15                          [32, 64, 4, 5]            --
# │    └─Conv2d: 2-16                           [32, 64, 4, 5]            36,928
# │    └─BatchNorm2d: 2-17                      [32, 64, 4, 5]            128
# │    └─ReLU: 2-18                             [32, 64, 4, 5]            --
# │    └─MaxPool2d: 2-19                        [32, 64, 1, 1]            --
# │    └─Dropout: 2-20                          [32, 64, 1, 1]            --
# ├─MaxPool2d: 1-2                              [32, 1, 64, 47]           --
# ├─TransformerEncoder: 1-3                     [47, 32, 64]              --
# │    └─ModuleList: 2-21                       --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [47, 32, 64]              83,008
# │    │    └─TransformerEncoderLayer: 3-2      [47, 32, 64]              83,008
# │    │    └─TransformerEncoderLayer: 3-3      [47, 32, 64]              83,008
# │    │    └─TransformerEncoderLayer: 3-4      [47, 32, 64]              83,008
# ├─Linear: 1-4                                 [32, 6]                   774
# ├─Dropout: 1-5                                [32, 6]                   --
# ├─Softmax: 1-6                                [32, 6]                   --
# ===============================================================================================
# Total params: 393,382
# Trainable params: 393,382
# Non-trainable params: 0
# Total mult-adds (G): 1.27
# ===============================================================================================
# Input size (MB): 3.08
# Forward/backward pass size (MB): 342.30
# Params size (MB): 1.31
# Estimated Total Size (MB): 346.68
# ===============================================================================================
